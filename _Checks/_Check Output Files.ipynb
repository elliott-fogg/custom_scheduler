# %%
import pandas as pd
import pickle
import os

# %%
input = pickle.load(open("input_files/baseline/baseline_2022-02.pkl", "rb"))

# %%
output = pickle.load(open("output_files/baseline/baseline_2022-02.pkl", "rb"))

# %%
output
# Out:
# {'final_completed_requests': {2770924: {'rID': 2770924,
#    'resource': '2m0a.clma.ogg',
#    'start': datetime.datetime(2022, 2, 1, 5, 5, 13),
#    'end': datetime.datetime(2022, 2, 1, 5, 20, 58),
#    'duration': 945,
#    'priority': 1571.0080916321465},
#   2769652: {'rID': 2769652,
#    'resource': '2m0a.clma.ogg',
#    'start': datetime.datetime(2022, 2, 1, 5, 20, 58),
#    'end': datetime.datetime(2022, 2, 1, 5, 29, 34),
#    'duration': 516,
#    'priority': 225.41357221645148},
#   2771126: {'rID': 2771126,
#    'resource': '2m0a.clma.ogg',
#    'start': datetime.datetime(2022, 2, 1, 5, 30),
#    'end': datetime.datetime(2022, 2, 1, 6, 25, 45),
#    'duration': 3345,
#    'priority': 2043.6947183434079},
#   2771154: {'rID': 2771154,
#    'resource': '2m0a.clma.ogg',
#    'start': datetime.datetime(2022, 2, 1, 6, 25, 45),
#    'end': datetime.datetime(2022, 2, 1, 7, 21, 30),
#    'duration': 3345,
#    'priority': 1946.6673050317563},
#   2770781: {'rID': 2770781,
# ...

# %%
len(data["final_completed_requests"])
# Out:
# 7902

# %%
input["all_requests"]
# Out:
#                                           original_windows  \
# 2858084  [{'start': 2022-04-24 05:36:00, 'end': 2022-04...
# 2864783  [{'start': 2022-04-29 00:10:14.577000, 'end': ...
# 2863891  [{'start': 2022-04-28 15:23:34.750000, 'end': ...
# 2862493  [{'start': 2022-04-27 16:20:12.933000, 'end': ...
# 2864850  [{'start': 2022-04-29 17:22:42.469000, 'end': ...
# ...                                                    ...
# 2858160  [{'start': 2022-04-24 09:10:04.143000, 'end': ...
# 2857817  [{'start': 2022-04-24 12:27:14.331000, 'end': ...
# 2864731  [{'start': 2022-04-29 05:38:46.885000, 'end': ...
# 2859925  [{'start': 2022-04-26 08:37:23.365000, 'end': ...
# 2860770  [{'start': 2022-04-26 14:50:03.467000, 'end': ...
#
#                                                    windows       id ipp_value  \
# 2858084  {'2m0a.clma.ogg': Timestamp('2022-04-24 05:36:...  2858084       1.0
# 2864783  {'2m0a.clma.coj': Timestamp('2022-04-29 10:42:...  2864783       1.0
# ...
