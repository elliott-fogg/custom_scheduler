# %%
from test_template_from_file import AltVariableWindowsTest as vwt
import json

# %%
# vwt1 = vwt("variableWindows_input", "variableWindows_output", "variableWindowsTest", [1.1, 1.5, 2.0, 10.0], 0.3)
vwt1 = vwt("variableWindows_input", "variableWindows_output", "variableWindowsTest", 3.0, 0.3)
vwt1.run()
# Out:
# File completed: variableWindowsTest_0.json
# File completed: variableWindowsTest_1.json
# 1  files remaining.
# 1 / 1 - variableWindowsTest_2.json - 16:46:18 26-02-2024
# Running Simulation 30 / 30...

# %%
data = json.load(open("variableWindows_output/variableWindowsTest/variableWindowsTest_2.json", "r"))
data
# Out:
# {'results': {'25': ['66',
#    '75',
#    '78',
#    '42',
#    '5',
#    '31',
#    '57',
#    '34',
#    '4',
#    '70',
#    '68',
#    '45',
#    '90',
#    '63',
#    '54',
#    '93',
#    '94',
#    '58',
#    '7',
#    '9',
#    '43',
#    '74',
#    '2',
#    '97',
#    '56',
#    '84',
#    '37',
#    '10',
#    '79',
#    '14',
#    '35',
#    '19',
#    '91',
#    '89',
#    '73',
#    '8',
#    '61',
#    '40',
#    '47',
#    '71',
#    '96',
#    '17',
#    '85',
#    '52',
#    '41',
#    '1',
#    '16',
#    '80',
#    '49',
#    '21',
#    '86',
#    '39',
#    '95'],
#   '76': ['66',
#    '75',
#    '78',
#    '42',
#    '5',
#    '31',
#    '57',
#    '34',
#    '4',
#    '70',
#    '68',
#    '45',
#    '90',
#    '63',
#    '54',
#    '93',
#    '94',
#    '58',
#    '7',
#    '9',
#    '43',
#    '74',
#    '2',
#    '97',
#    '56',
#    '84',
#    '37',
#    '10',
#    '79',
#    '14',
#    '35',
#    '19',
#    '91',
#    '89',
#    '73',
#    '8',
# ...

# %%
data.keys()
# Out:
# dict_keys(['results', 'base_requests', 'proposals', 'base_results'])

# %%
print(data["base_results"])
# Out:
# ['66', '75', '78', '42', '5', '31', '57', '34', '4', '70', '68', '45', '90', '63', '54', '93', '94', '58', '7', '9', '43', '74', '2', '97', '56', '84', '37', '10', '79', '14', '35', '19', '91', '89', '73', '8', '61', '40', '47', '71', '96', '17', '85', '52', '41', '1', '16', '80', '49', '21', '86', '39', '95']

# %%
for r in data["results"]:
    # print([v for v in data["results"][r] if v in data["base_results"]])
    print([v for v in data["results"][r] if v not in data["base_results"]])
    print([v for v in data["base_results"] if v not in data["results"][r]])
    print()

# for br in data["base_results"]:
#     if br in data["results"]:
#         modified_results = data["results"][br]
#         if br in modified_results:
#             print(0)
#         else:
#             print(1)
# Out:
# []
# []
#
# []
# []
#
# []
# []
#
# []
# []
#
# []
# []
#
# []
# []
#
# []
# []
#
# []
# []
#
# []
# []
#
# []
# []
#
# []
# []
#
# []
# []
#
# []
# []
#
# []
# []
#
# []
# []
#
# []
# []
#
# []
# []
#
# []
# []
#
# []
# []
#
# []
# []
#
# []
# []
#
# []
# []
#
# []
# []
#
# []
# []
#
# []
# []
#
# []
# []
#
# []
# []
#
# []
# []
#
# []
# []
#
# []
# []
