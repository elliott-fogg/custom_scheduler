# %% [markdown]
# ## Import libraries and set random seed

# %%
from gurobipy import Model, GRB, tuplelist, quicksum
from gurobipy import read as gurobi_read_model
import json
import random
import math

random.seed(3)

# %% [markdown]
# ## Set scheduler parameters

# %%
START_TIME = 0
SLICE_SIZE_MINUTES = 5
HORIZON_DAYS = 1

slice_size = SLICE_SIZE_MINUTES*60
horizon = HORIZON_DAYS*24*60*60
print(f"Slicesize: {slice_size}s")
print(f"Scheduling Horizon: {horizon}s")
# Out:
# Slicesize: 300s
# Scheduling Horizon: 86400s

# %% [markdown]
# ## Required Functions

# %% [markdown]
# ### Possible Starts

# %%
class PossibleStart(object):
    def __init__(self, resource, slice_starts, internal_start):
        self.resource = resource
        self.first_slice_start = slice_starts[0]
        self.all_slice_starts = slice_starts
        self.internal_start = internal_start

    def __lt__(self, other):
        return self.first_slice_start < other.first_slice_start

    def __eq__(self, other):
        return self.first_slice_start == self.first_slice_start

    def __gt__(self, other):
        return self.first_slice_start > self.first_slice_start
        

def get_slices(intervals, resource, duration, slice_length):
    slices = []
    internal_starts = []
    for t in intervals: 
        start = int(math.floor(float(t["start"])/float(slice_length))*slice_length) # Start of the time_slice that this starts in
        internal_start = t["start"]                                                 # Actual start of this observation window
        end_time = internal_start + duration                                        # End of this observation window

        while (t["end"] - start) >= duration:
            tmp = range(start, internal_start+duration, slice_length)    # Generate a range of slices that will be occupied for this start and duration
            slices.append(tmp)
            internal_starts.append(internal_start)
            start += slice_length                                        # Moving on to the next potential start, so move the Start up to the next slice
            internal_start = start                                       # As only the first potential start in a window will be internal, make the 
                                                                         # next Internal Start an external start
    # return slices, internal_starts
    ps_list = []
    idx = 0
    for w in slices:
        ps_list.append(PossibleStart(resource, w, internal_starts[idx]))
        idx += 1

    return ps_list

# %% [markdown]
# #### Test

# %%
# TEST:
intervals = [{"start": 0, "end": 30}, {"start": 60, "end": 90}]
possible_starts = get_slices(intervals, 13, 3, slice_size)
print(possible_starts[1])
# Out:
# <__main__.PossibleStart object at 0x0000025C2EA63AD0>

# %% [markdown]
# ### Build Data Sctructures
#
# Build the Yik and the aikt for generating the Optimizer Constraints from.
#
# Requests must be a list of requests, which should have:
# * free_windows_dict
# * duration
# * resID
# * priority

# %% [markdown]
# #### New Code

# %%
def build_data_structures(requests, slice_length):
    yik = []
    aikt = {}

    for r in requests:
        yik_entries = []
        possible_starts = []
        for resource in r["free_windows_dict"].keys():
            possible_starts.extend(get_slices(r["free_windows_dict"][resource], resource, r["duration"], slice_length))
        possible_starts.sort()
    
        w_idx = 0
        for ps in possible_starts:
            yik_idx = len(yik)
            yik_entries.append(yik_idx)
            scheduled = 0 # Option to set to 1 for a Warm Start would go here
            yik.append([r["resID"], w_idx, r["priority"], ps.resource, scheduled])
            w_idx += 1
    
            for s in ps.all_slice_starts:
                slice_hash = f"resource_{ps.resource}_start_{repr(s)}_length_{repr(slice_length)}"
                if slice_hash not in aikt:
                    aikt[slice_hash] = []
                aikt[slice_hash].append(yik_idx)
    return (yik, aikt)

# %% [markdown]
# #### Test

# %%
requests = [
    {"free_windows_dict": {"t1": [{"start": 0, "end": 23}, {"start": 27, "end": 88}]},
     "duration": 10,
     "resID": 3,
     "priority": 5},
    {"free_windows_dict": {"t1": [{"start": 24, "end": 63}]},
     "duration": 13,
     "resID": 1,
     "priority": 4}
]

build_data_structures(requests, 5)
# Out:
# ([[3, 0, 5, 't1', 0],
#   [3, 1, 5, 't1', 0],
#   [3, 2, 5, 't1', 0],
#   [3, 3, 5, 't1', 0],
#   [3, 4, 5, 't1', 0],
#   [3, 5, 5, 't1', 0],
#   [3, 6, 5, 't1', 0],
#   [3, 7, 5, 't1', 0],
#   [3, 8, 5, 't1', 0],
#   [3, 9, 5, 't1', 0],
#   [3, 10, 5, 't1', 0],
#   [3, 11, 5, 't1', 0],
#   [3, 12, 5, 't1', 0],
#   [3, 13, 5, 't1', 0],
#   [1, 0, 4, 't1', 0],
#   [1, 1, 4, 't1', 0],
#   [1, 2, 4, 't1', 0],
#   [1, 3, 4, 't1', 0],
#   [1, 4, 4, 't1', 0],
#   [1, 5, 4, 't1', 0],
#   [1, 6, 4, 't1', 0]],
#  {'resource_t1_start_0_length_5': [0],
#   'resource_t1_start_5_length_5': [0, 1],
#   'resource_t1_start_10_length_5': [1, 2],
#   'resource_t1_start_15_length_5': [2],
#   'resource_t1_start_25_length_5': [3, 14, 15],
#   'resource_t1_start_30_length_5': [3, 4, 14, 15, 16],
#   'resource_t1_start_35_length_5': [3, 4, 5, 14, 15, 16, 17],
#   'resource_t1_start_40_length_5': [5, 6, 16, 17, 18],
#   'resource_t1_start_45_length_5': [6, 7, 17, 18, 19],
#   'resource_t1_start_50_length_5': [7, 8, 18, 19, 20],
#   'resource_t1_start_55_length_5': [8, 9, 19, 20],
#   'resource_t1_start_60_length_5': [9, 10, 20],
#   'resource_t1_start_65_length_5': [10, 11],
#   'resource_t1_start_70_length_5': [11, 12],
#   'resource_t1_start_75_length_5': [12, 13],
#   'resource_t1_start_80_length_5': [13],
#   'resource_t1_start_20_length_5': [14]})

# %% [markdown]
# ### Legacy Code

# %%
        # first we need to build up the list of discretized slices that each
        # reservation can begin in. These are represented as attributes
        # that get attached to the reservation object. 
        # The new attributes are: 
        # slices_dict
        # internal_starts_dict
        # and the dicts are keyed by resource. 
        # the description of slices and internal starts is in intervals.py

        print(self.Yik)
        print(self.aikt)
        sys.exit()

        for r in self.reservation_list:
            r.Yik_entries = []
            r.possible_starts = []
            print("free_windows_dict")
            print(r.free_windows_dict)
            for resource in r.free_windows_dict.keys():
                r.possible_starts.extend(self.get_slices( r.free_windows_dict[resource], resource, r.duration))
            # reorder PossibleStarts
            r.possible_starts.sort()
            # build aikt
            w_idx = 0
            for ps in r.possible_starts:
                Yik_idx = len(self.Yik)
                r.Yik_entries.append(Yik_idx)
                # set the initial warm start solution
                scheduled = 0
                if r.previous_solution_reservation and r.previous_solution_reservation.scheduled_start == ps.internal_start and r.previous_solution_reservation.scheduled_resource == ps.resource:
                    scheduled = 1
                # now w_idx is the index into r.possible_starts, which have
                # been reordered by time.
                self.Yik.append([r.resID, w_idx, r.priority, ps.resource, scheduled])
                w_idx += 1
                # build aikt
                for s in ps.all_slice_starts:
                    key, exists = self.hash_slice(s, ps.resource, self.time_slicing_dict[ps.resource][1])
    #                        if key in self.aikt:
                    if exists:
                        self.aikt[key].append(Yik_idx)
                    else:
                        self.aikt[key] = [Yik_idx]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 10
#       1 # first we need to build up the list of discretized slices that each
#       2 # reservation can begin in. These are represented as attributes
#       3 # that get attached to the reservation object.
#    (...)
#       7 # and the dicts are keyed by resource.
#       8 # the description of slices and internal starts is in intervals.py
# ---> 10 print(self.Yik)
#      11 print(self.aikt)
#      12 sys.exit()
#
# NameError: name 'self' is not defined

# %% [markdown]
# #### Old Code

# %%
# Translate Requests into widx slices
slices = {}

for request_id in range(len(requests)):
    r = requests[request_id]
    window_start = r["window_start"]
    window_end = r["window_end"]
    length = r["length"]
    priority = r["priority"]

    # print(request_id, window_start, window_end, length)

    for r, r_slices in resource_slices.items():
        window_slices = list(range(window_start, window_end+1, slice_size))
        resource_window_slices = [t for t in r_slices if t in window_slices] # Will need to redo this part

        # print(window_slices)
        # print(resource_window_slices)
        # print(r_slices)

        possible_windows = []
        for t1 in resource_window_slices:
            valid = True
            for section in range(math.ceil(length / slice_size)):
                if (t1 + section) not in resource_window_slices:
                    valid = False
                    break

            if valid:
                print("valid")
                possible_windows.append(t1)


for rid in range(len(requests)):

    r = requests[rid]
    w_start = r["window_start"]
    w_end = r["window_end"]
    length = r["length"]
    priority = r["priority"]

    print(rid, w_start, w_end, length)
    
    for resource, hours in resource_slices.items():
        # Determine if the current start can fit in the time slices for this resource
        initial_window = range(w_start, end+1)
        print(initial_window)
        overlap = [t for t in hours if t in initial_window]
        print(overlap)
        possible_windows = []
        for t1 in overlap:
            valid = True
            for section in range(length):
                if (t1 + section) not in overlap:
                    valid = False
                    break
            
            if valid:
                # Add to possible_windows
                possible_windows.append(t1)
                
        # print(possible_windows)
        for w in possible_windows:
            name = f"TEL-{resource}_ID-{rid}_ST-{w}"
            wnum = w + section

            slices[name] = {
                "rid": rid,
                "priority": priority,
                "resource": resource,
                "start": w,
                "duration": length
            }

    print()

print("HELLO")

for s in slices:
    print(s)
    # print(slices[s])
    print()
# print(aikt)
# Out:
# 0 31190 77678 8946
# range(31190, 82966)
# [31200, 31500, 31800, 32100, 32400, 32700, 33000, 33300, 33600, 33900, 34200, 34500, 34800, 35100, 35400, 35700, 36000, 36300, 36600, 36900, 37200, 37500, 37800, 38100, 38400, 38700, 39000, 39300, 39600, 39900, 40200, 40500, 40800, 41100, 41400, 41700, 42000, 42300, 42600, 42900, 43200, 43500, 43800, 44100, 44400, 44700, 45000, 45300, 45600, 45900, 46200, 46500, 46800, 47100, 47400, 47700, 48000, 48300, 48600, 48900, 49200, 49500, 49800, 50100, 50400, 50700, 51000, 51300, 51600, 51900, 52200, 52500, 52800, 53100, 53400, 53700, 54000, 54300, 54600, 54900, 55200, 55500, 55800, 56100, 56400, 56700, 57000, 57300, 57600, 57900, 58200, 58500, 58800, 59100, 59400, 59700, 60000, 60300, 60600, 60900, 61200, 61500, 61800, 62100, 62400, 62700, 63000, 63300, 63600, 63900, 64200, 64500, 64800, 65100, 65400, 65700, 66000, 66300, 66600, 66900, 67200, 67500, 67800, 68100, 68400, 68700, 69000, 69300, 69600, 69900, 70200, 70500, 70800, 71100, 71400, 71700, 72000, 72300, 72600, 72900, 73200, 73500, 73800, 74100, 74400, 74700, 75000, 75300, 75600, 75900, 76200, 76500, 76800, 77100, 77400, 77700, 78000, 78300, 78600, 78900, 79200, 79500, 79800, 80100, 80400, 80700, 81000, 81300, 81600, 81900, 82200, 82500, 82800]
#
# 1 48490 79157 7796
# range(48490, 82966)
# [48600, 48900, 49200, 49500, 49800, 50100, 50400, 50700, 51000, 51300, 51600, 51900, 52200, 52500, 52800, 53100, 53400, 53700, 54000, 54300, 54600, 54900, 55200, 55500, 55800, 56100, 56400, 56700, 57000, 57300, 57600, 57900, 58200, 58500, 58800, 59100, 59400, 59700, 60000, 60300, 60600, 60900, 61200, 61500, 61800, 62100, 62400, 62700, 63000, 63300, 63600, 63900, 64200, 64500, 64800, 65100, 65400, 65700, 66000, 66300, 66600, 66900, 67200, 67500, 67800, 68100, 68400, 68700, 69000, 69300, 69600, 69900, 70200, 70500, 70800, 71100, 71400, 71700, 72000, 72300, 72600, 72900, 73200, 73500, 73800, 74100, 74400, 74700, 75000, 75300, 75600, 75900, 76200, 76500, 76800, 77100, 77400, 77700, 78000, 78300, 78600, 78900, 79200, 79500, 79800, 80100, 80400, 80700, 81000, 81300, 81600, 81900, 82200, 82500, 82800]
#
# 2 8588 79377 245
# range(8588, 82966)
# [8700, 9000, 9300, 9600, 9900, 10200, 10500, 10800, 11100, 11400, 11700, 12000, 12300, 12600, 12900, 13200, 13500, 13800, 14100, 14400, 14700, 15000, 15300, 15600, 15900, 16200, 16500, 16800, 17100, 17400, 17700, 18000, 18300, 18600, 18900, 19200, 19500, 19800, 20100, 20400, 20700, 21000, 21300, 21600, 21900, 22200, 22500, 22800, 23100, 23400, 23700, 24000, 24300, 24600, 24900, 25200, 25500, 25800, 26100, 26400, 26700, 27000, 27300, 27600, 27900, 28200, 28500, 28800, 29100, 29400, 29700, 30000, 30300, 30600, 30900, 31200, 31500, 31800, 32100, 32400, 32700, 33000, 33300, 33600, 33900, 34200, 34500, 34800, 35100, 35400, 35700, 36000, 36300, 36600, 36900, 37200, 37500, 37800, 38100, 38400, 38700, 39000, 39300, 39600, 39900, 40200, 40500, 40800, 41100, 41400, 41700, 42000, 42300, 42600, 42900, 43200, 43500, 43800, 44100, 44400, 44700, 45000, 45300, 45600, 45900, 46200, 46500, 46800, 47100, 47400, 47700, 48000, 48300, 48600, 48900, 49200, 49500, 49800, 50100, 50400, 50700, 51000, 51300, 51600, 51900, 52200, 52500, 52800, 53100, 53400, 53700, 54000, 54300, 54600, 54900, 55200, 55500, 55800, 56100, 56400, 56700, 57000, 57300, 57600, 57900, 58200, 58500, 58800, 59100, 59400, 59700, 60000, 60300, 60600, 60900, 61200, 61500, 61800, 62100, 62400, 62700, 63000, 63300, 63600, 63900, 64200, 64500, 64800, 65100, 65400, 65700, 66000, 66300, 66600, 66900, 67200, 67500, 67800, 68100, 68400, 68700, 69000, 69300, 69600, 69900, 70200, 70500, 70800, 71100, 71400, 71700, 72000, 72300, 72600, 72900, 73200, 73500, 73800, 74100, 74400, 74700, 75000, 75300, 75600, 75900, 76200, 76500, 76800, 77100, 77400, 77700, 78000, 78300, 78600, 78900, 79200, 79500, 79800, 80100, 80400, 80700, 81000, 81300, 81600, 81900, 82200, 82500, 82800]
#
# 3 33994 72192 3869
# range(33994, 82966)
# [34200, 34500, 34800, 35100, 35400, 35700, 36000, 36300, 36600, 36900, 37200, 37500, 37800, 38100, 38400, 38700, 39000, 39300, 39600, 39900, 40200, 40500, 40800, 41100, 41400, 41700, 42000, 42300, 42600, 42900, 43200, 43500, 43800, 44100, 44400, 44700, 45000, 45300, 45600, 45900, 46200, 46500, 46800, 47100, 47400, 47700, 48000, 48300, 48600, 48900, 49200, 49500, 49800, 50100, 50400, 50700, 51000, 51300, 51600, 51900, 52200, 52500, 52800, 53100, 53400, 53700, 54000, 54300, 54600, 54900, 55200, 55500, 55800, 56100, 56400, 56700, 57000, 57300, 57600, 57900, 58200, 58500, 58800, 59100, 59400, 59700, 60000, 60300, 60600, 60900, 61200, 61500, 61800, 62100, 62400, 62700, 63000, 63300, 63600, 63900, 64200, 64500, 64800, 65100, 65400, 65700, 66000, 66300, 66600, 66900, 67200, 67500, 67800, 68100, 68400, 68700, 69000, 69300, 69600, 69900, 70200, 70500, 70800, 71100, 71400, 71700, 72000, 72300, 72600, 72900, 73200, 73500, 73800, 74100, 74400, 74700, 75000, 75300, 75600, 75900, 76200, 76500, 76800, 77100, 77400, 77700, 78000, 78300, 78600, 78900, 79200, 79500, 79800, 80100, 80400, 80700, 81000, 81300, 81600, 81900, 82200, 82500, 82800]
#
# 4 61638 70906 9035
# range(61638, 82966)
# [61800, 62100, 62400, 62700, 63000, 63300, 63600, 63900, 64200, 64500, 64800, 65100, 65400, 65700, 66000, 66300, 66600, 66900, 67200, 67500, 67800, 68100, 68400, 68700, 69000, 69300, 69600, 69900, 70200, 70500, 70800, 71100, 71400, 71700, 72000, 72300, 72600, 72900, 73200, 73500, 73800, 74100, 74400, 74700, 75000, 75300, 75600, 75900, 76200, 76500, 76800, 77100, 77400, 77700, 78000, 78300, 78600, 78900, 79200, 79500, 79800, 80100, 80400, 80700, 81000, 81300, 81600, 81900, 82200, 82500, 82800]
#
# 5 52053 83763 2497
# range(52053, 82966)
# [52200, 52500, 52800, 53100, 53400, 53700, 54000, 54300, 54600, 54900, 55200, 55500, 55800, 56100, 56400, 56700, 57000, 57300, 57600, 57900, 58200, 58500, 58800, 59100, 59400, 59700, 60000, 60300, 60600, 60900, 61200, 61500, 61800, 62100, 62400, 62700, 63000, 63300, 63600, 63900, 64200, 64500, 64800, 65100, 65400, 65700, 66000, 66300, 66600, 66900, 67200, 67500, 67800, 68100, 68400, 68700, 69000, 69300, 69600, 69900, 70200, 70500, 70800, 71100, 71400, 71700, 72000, 72300, 72600, 72900, 73200, 73500, 73800, 74100, 74400, 74700, 75000, 75300, 75600, 75900, 76200, 76500, 76800, 77100, 77400, 77700, 78000, 78300, 78600, 78900, 79200, 79500, 79800, 80100, 80400, 80700, 81000, 81300, 81600, 81900, 82200, 82500, 82800]
#
# 6 19873 83212 8601
# range(19873, 82966)
# [20100, 20400, 20700, 21000, 21300, 21600, 21900, 22200, 22500, 22800, 23100, 23400, 23700, 24000, 24300, 24600, 24900, 25200, 25500, 25800, 26100, 26400, 26700, 27000, 27300, 27600, 27900, 28200, 28500, 28800, 29100, 29400, 29700, 30000, 30300, 30600, 30900, 31200, 31500, 31800, 32100, 32400, 32700, 33000, 33300, 33600, 33900, 34200, 34500, 34800, 35100, 35400, 35700, 36000, 36300, 36600, 36900, 37200, 37500, 37800, 38100, 38400, 38700, 39000, 39300, 39600, 39900, 40200, 40500, 40800, 41100, 41400, 41700, 42000, 42300, 42600, 42900, 43200, 43500, 43800, 44100, 44400, 44700, 45000, 45300, 45600, 45900, 46200, 46500, 46800, 47100, 47400, 47700, 48000, 48300, 48600, 48900, 49200, 49500, 49800, 50100, 50400, 50700, 51000, 51300, 51600, 51900, 52200, 52500, 52800, 53100, 53400, 53700, 54000, 54300, 54600, 54900, 55200, 55500, 55800, 56100, 56400, 56700, 57000, 57300, 57600, 57900, 58200, 58500, 58800, 59100, 59400, 59700, 60000, 60300, 60600, 60900, 61200, 61500, 61800, 62100, 62400, 62700, 63000, 63300, 63600, 63900, 64200, 64500, 64800, 65100, 65400, 65700, 66000, 66300, 66600, 66900, 67200, 67500, 67800, 68100, 68400, 68700, 69000, 69300, 69600, 69900, 70200, 70500, 70800, 71100, 71400, 71700, 72000, 72300, 72600, 72900, 73200, 73500, 73800, 74100, 74400, 74700, 75000, 75300, 75600, 75900, 76200, 76500, 76800, 77100, 77400, 77700, 78000, 78300, 78600, 78900, 79200, 79500, 79800, 80100, 80400, 80700, 81000, 81300, 81600, 81900, 82200, 82500, 82800]
#
# 7 1985 8392 2641
# range(1985, 82966)
# [2100, 2400, 2700, 3000, 3300, 3600, 3900, 4200, 4500, 4800, 5100, 5400, 5700, 6000, 6300, 6600, 6900, 7200, 7500, 7800, 8100, 8400, 8700, 9000, 9300, 9600, 9900, 10200, 10500, 10800, 11100, 11400, 11700, 12000, 12300, 12600, 12900, 13200, 13500, 13800, 14100, 14400, 14700, 15000, 15300, 15600, 15900, 16200, 16500, 16800, 17100, 17400, 17700, 18000, 18300, 18600, 18900, 19200, 19500, 19800, 20100, 20400, 20700, 21000, 21300, 21600, 21900, 22200, 22500, 22800, 23100, 23400, 23700, 24000, 24300, 24600, 24900, 25200, 25500, 25800, 26100, 26400, 26700, 27000, 27300, 27600, 27900, 28200, 28500, 28800, 29100, 29400, 29700, 30000, 30300, 30600, 30900, 31200, 31500, 31800, 32100, 32400, 32700, 33000, 33300, 33600, 33900, 34200, 34500, 34800, 35100, 35400, 35700, 36000, 36300, 36600, 36900, 37200, 37500, 37800, 38100, 38400, 38700, 39000, 39300, 39600, 39900, 40200, 40500, 40800, 41100, 41400, 41700, 42000, 42300, 42600, 42900, 43200, 43500, 43800, 44100, 44400, 44700, 45000, 45300, 45600, 45900, 46200, 46500, 46800, 47100, 47400, 47700, 48000, 48300, 48600, 48900, 49200, 49500, 49800, 50100, 50400, 50700, 51000, 51300, 51600, 51900, 52200, 52500, 52800, 53100, 53400, 53700, 54000, 54300, 54600, 54900, 55200, 55500, 55800, 56100, 56400, 56700, 57000, 57300, 57600, 57900, 58200, 58500, 58800, 59100, 59400, 59700, 60000, 60300, 60600, 60900, 61200, 61500, 61800, 62100, 62400, 62700, 63000, 63300, 63600, 63900, 64200, 64500, 64800, 65100, 65400, 65700, 66000, 66300, 66600, 66900, 67200, 67500, 67800, 68100, 68400, 68700, 69000, 69300, 69600, 69900, 70200, 70500, 70800, 71100, 71400, 71700, 72000, 72300, 72600, 72900, 73200, 73500, 73800, 74100, 74400, 74700, 75000, 75300, 75600, 75900, 76200, 76500, 76800, 77100, 77400, 77700, 78000, 78300, 78600, 78900, 79200, 79500, 79800, 80100, 80400, 80700, 81000, 81300, 81600, 81900, 82200, 82500, 82800]
#
# 8 5608 39487 538
# range(5608, 82966)
# [5700, 6000, 6300, 6600, 6900, 7200, 7500, 7800, 8100, 8400, 8700, 9000, 9300, 9600, 9900, 10200, 10500, 10800, 11100, 11400, 11700, 12000, 12300, 12600, 12900, 13200, 13500, 13800, 14100, 14400, 14700, 15000, 15300, 15600, 15900, 16200, 16500, 16800, 17100, 17400, 17700, 18000, 18300, 18600, 18900, 19200, 19500, 19800, 20100, 20400, 20700, 21000, 21300, 21600, 21900, 22200, 22500, 22800, 23100, 23400, 23700, 24000, 24300, 24600, 24900, 25200, 25500, 25800, 26100, 26400, 26700, 27000, 27300, 27600, 27900, 28200, 28500, 28800, 29100, 29400, 29700, 30000, 30300, 30600, 30900, 31200, 31500, 31800, 32100, 32400, 32700, 33000, 33300, 33600, 33900, 34200, 34500, 34800, 35100, 35400, 35700, 36000, 36300, 36600, 36900, 37200, 37500, 37800, 38100, 38400, 38700, 39000, 39300, 39600, 39900, 40200, 40500, 40800, 41100, 41400, 41700, 42000, 42300, 42600, 42900, 43200, 43500, 43800, 44100, 44400, 44700, 45000, 45300, 45600, 45900, 46200, 46500, 46800, 47100, 47400, 47700, 48000, 48300, 48600, 48900, 49200, 49500, 49800, 50100, 50400, 50700, 51000, 51300, 51600, 51900, 52200, 52500, 52800, 53100, 53400, 53700, 54000, 54300, 54600, 54900, 55200, 55500, 55800, 56100, 56400, 56700, 57000, 57300, 57600, 57900, 58200, 58500, 58800, 59100, 59400, 59700, 60000, 60300, 60600, 60900, 61200, 61500, 61800, 62100, 62400, 62700, 63000, 63300, 63600, 63900, 64200, 64500, 64800, 65100, 65400, 65700, 66000, 66300, 66600, 66900, 67200, 67500, 67800, 68100, 68400, 68700, 69000, 69300, 69600, 69900, 70200, 70500, 70800, 71100, 71400, 71700, 72000, 72300, 72600, 72900, 73200, 73500, 73800, 74100, 74400, 74700, 75000, 75300, 75600, 75900, 76200, 76500, 76800, 77100, 77400, 77700, 78000, 78300, 78600, 78900, 79200, 79500, 79800, 80100, 80400, 80700, 81000, 81300, 81600, 81900, 82200, 82500, 82800]
#
# 9 61964 77955 6380
# range(61964, 82966)
# [62100, 62400, 62700, 63000, 63300, 63600, 63900, 64200, 64500, 64800, 65100, 65400, 65700, 66000, 66300, 66600, 66900, 67200, 67500, 67800, 68100, 68400, 68700, 69000, 69300, 69600, 69900, 70200, 70500, 70800, 71100, 71400, 71700, 72000, 72300, 72600, 72900, 73200, 73500, 73800, 74100, 74400, 74700, 75000, 75300, 75600, 75900, 76200, 76500, 76800, 77100, 77400, 77700, 78000, 78300, 78600, 78900, 79200, 79500, 79800, 80100, 80400, 80700, 81000, 81300, 81600, 81900, 82200, 82500, 82800]
#
# 10 51768 75616 7314
# range(51768, 82966)
# [51900, 52200, 52500, 52800, 53100, 53400, 53700, 54000, 54300, 54600, 54900, 55200, 55500, 55800, 56100, 56400, 56700, 57000, 57300, 57600, 57900, 58200, 58500, 58800, 59100, 59400, 59700, 60000, 60300, 60600, 60900, 61200, 61500, 61800, 62100, 62400, 62700, 63000, 63300, 63600, 63900, 64200, 64500, 64800, 65100, 65400, 65700, 66000, 66300, 66600, 66900, 67200, 67500, 67800, 68100, 68400, 68700, 69000, 69300, 69600, 69900, 70200, 70500, 70800, 71100, 71400, 71700, 72000, 72300, 72600, 72900, 73200, 73500, 73800, 74100, 74400, 74700, 75000, 75300, 75600, 75900, 76200, 76500, 76800, 77100, 77400, 77700, 78000, 78300, 78600, 78900, 79200, 79500, 79800, 80100, 80400, 80700, 81000, 81300, 81600, 81900, 82200, 82500, 82800]
#
# 11 12773 47909 617
# range(12773, 82966)
# [12900, 13200, 13500, 13800, 14100, 14400, 14700, 15000, 15300, 15600, 15900, 16200, 16500, 16800, 17100, 17400, 17700, 18000, 18300, 18600, 18900, 19200, 19500, 19800, 20100, 20400, 20700, 21000, 21300, 21600, 21900, 22200, 22500, 22800, 23100, 23400, 23700, 24000, 24300, 24600, 24900, 25200, 25500, 25800, 26100, 26400, 26700, 27000, 27300, 27600, 27900, 28200, 28500, 28800, 29100, 29400, 29700, 30000, 30300, 30600, 30900, 31200, 31500, 31800, 32100, 32400, 32700, 33000, 33300, 33600, 33900, 34200, 34500, 34800, 35100, 35400, 35700, 36000, 36300, 36600, 36900, 37200, 37500, 37800, 38100, 38400, 38700, 39000, 39300, 39600, 39900, 40200, 40500, 40800, 41100, 41400, 41700, 42000, 42300, 42600, 42900, 43200, 43500, 43800, 44100, 44400, 44700, 45000, 45300, 45600, 45900, 46200, 46500, 46800, 47100, 47400, 47700, 48000, 48300, 48600, 48900, 49200, 49500, 49800, 50100, 50400, 50700, 51000, 51300, 51600, 51900, 52200, 52500, 52800, 53100, 53400, 53700, 54000, 54300, 54600, 54900, 55200, 55500, 55800, 56100, 56400, 56700, 57000, 57300, 57600, 57900, 58200, 58500, 58800, 59100, 59400, 59700, 60000, 60300, 60600, 60900, 61200, 61500, 61800, 62100, 62400, 62700, 63000, 63300, 63600, 63900, 64200, 64500, 64800, 65100, 65400, 65700, 66000, 66300, 66600, 66900, 67200, 67500, 67800, 68100, 68400, 68700, 69000, 69300, 69600, 69900, 70200, 70500, 70800, 71100, 71400, 71700, 72000, 72300, 72600, 72900, 73200, 73500, 73800, 74100, 74400, 74700, 75000, 75300, 75600, 75900, 76200, 76500, 76800, 77100, 77400, 77700, 78000, 78300, 78600, 78900, 79200, 79500, 79800, 80100, 80400, 80700, 81000, 81300, 81600, 81900, 82200, 82500, 82800]
#
# 12 28440 64865 4256
# range(28440, 82966)
# [28500, 28800, 29100, 29400, 29700, 30000, 30300, 30600, 30900, 31200, 31500, 31800, 32100, 32400, 32700, 33000, 33300, 33600, 33900, 34200, 34500, 34800, 35100, 35400, 35700, 36000, 36300, 36600, 36900, 37200, 37500, 37800, 38100, 38400, 38700, 39000, 39300, 39600, 39900, 40200, 40500, 40800, 41100, 41400, 41700, 42000, 42300, 42600, 42900, 43200, 43500, 43800, 44100, 44400, 44700, 45000, 45300, 45600, 45900, 46200, 46500, 46800, 47100, 47400, 47700, 48000, 48300, 48600, 48900, 49200, 49500, 49800, 50100, 50400, 50700, 51000, 51300, 51600, 51900, 52200, 52500, 52800, 53100, 53400, 53700, 54000, 54300, 54600, 54900, 55200, 55500, 55800, 56100, 56400, 56700, 57000, 57300, 57600, 57900, 58200, 58500, 58800, 59100, 59400, 59700, 60000, 60300, 60600, 60900, 61200, 61500, 61800, 62100, 62400, 62700, 63000, 63300, 63600, 63900, 64200, 64500, 64800, 65100, 65400, 65700, 66000, 66300, 66600, 66900, 67200, 67500, 67800, 68100, 68400, 68700, 69000, 69300, 69600, 69900, 70200, 70500, 70800, 71100, 71400, 71700, 72000, 72300, 72600, 72900, 73200, 73500, 73800, 74100, 74400, 74700, 75000, 75300, 75600, 75900, 76200, 76500, 76800, 77100, 77400, 77700, 78000, 78300, 78600, 78900, 79200, 79500, 79800, 80100, 80400, 80700, 81000, 81300, 81600, 81900, 82200, 82500, 82800]
#
# 13 39456 82136 6930
# range(39456, 82966)
# [39600, 39900, 40200, 40500, 40800, 41100, 41400, 41700, 42000, 42300, 42600, 42900, 43200, 43500, 43800, 44100, 44400, 44700, 45000, 45300, 45600, 45900, 46200, 46500, 46800, 47100, 47400, 47700, 48000, 48300, 48600, 48900, 49200, 49500, 49800, 50100, 50400, 50700, 51000, 51300, 51600, 51900, 52200, 52500, 52800, 53100, 53400, 53700, 54000, 54300, 54600, 54900, 55200, 55500, 55800, 56100, 56400, 56700, 57000, 57300, 57600, 57900, 58200, 58500, 58800, 59100, 59400, 59700, 60000, 60300, 60600, 60900, 61200, 61500, 61800, 62100, 62400, 62700, 63000, 63300, 63600, 63900, 64200, 64500, 64800, 65100, 65400, 65700, 66000, 66300, 66600, 66900, 67200, 67500, 67800, 68100, 68400, 68700, 69000, 69300, 69600, 69900, 70200, 70500, 70800, 71100, 71400, 71700, 72000, 72300, 72600, 72900, 73200, 73500, 73800, 74100, 74400, 74700, 75000, 75300, 75600, 75900, 76200, 76500, 76800, 77100, 77400, 77700, 78000, 78300, 78600, 78900, 79200, 79500, 79800, 80100, 80400, 80700, 81000, 81300, 81600, 81900, 82200, 82500, 82800]
#
# 14 50576 75238 5779
# range(50576, 82966)
# [50700, 51000, 51300, 51600, 51900, 52200, 52500, 52800, 53100, 53400, 53700, 54000, 54300, 54600, 54900, 55200, 55500, 55800, 56100, 56400, 56700, 57000, 57300, 57600, 57900, 58200, 58500, 58800, 59100, 59400, 59700, 60000, 60300, 60600, 60900, 61200, 61500, 61800, 62100, 62400, 62700, 63000, 63300, 63600, 63900, 64200, 64500, 64800, 65100, 65400, 65700, 66000, 66300, 66600, 66900, 67200, 67500, 67800, 68100, 68400, 68700, 69000, 69300, 69600, 69900, 70200, 70500, 70800, 71100, 71400, 71700, 72000, 72300, 72600, 72900, 73200, 73500, 73800, 74100, 74400, 74700, 75000, 75300, 75600, 75900, 76200, 76500, 76800, 77100, 77400, 77700, 78000, 78300, 78600, 78900, 79200, 79500, 79800, 80100, 80400, 80700, 81000, 81300, 81600, 81900, 82200, 82500, 82800]
#
# 15 53421 76686 9602
# range(53421, 82966)
# [53700, 54000, 54300, 54600, 54900, 55200, 55500, 55800, 56100, 56400, 56700, 57000, 57300, 57600, 57900, 58200, 58500, 58800, 59100, 59400, 59700, 60000, 60300, 60600, 60900, 61200, 61500, 61800, 62100, 62400, 62700, 63000, 63300, 63600, 63900, 64200, 64500, 64800, 65100, 65400, 65700, 66000, 66300, 66600, 66900, 67200, 67500, 67800, 68100, 68400, 68700, 69000, 69300, 69600, 69900, 70200, 70500, 70800, 71100, 71400, 71700, 72000, 72300, 72600, 72900, 73200, 73500, 73800, 74100, 74400, 74700, 75000, 75300, 75600, 75900, 76200, 76500, 76800, 77100, 77400, 77700, 78000, 78300, 78600, 78900, 79200, 79500, 79800, 80100, 80400, 80700, 81000, 81300, 81600, 81900, 82200, 82500, 82800]
#
# 16 3756 44140 4612
# range(3756, 82966)
# [3900, 4200, 4500, 4800, 5100, 5400, 5700, 6000, 6300, 6600, 6900, 7200, 7500, 7800, 8100, 8400, 8700, 9000, 9300, 9600, 9900, 10200, 10500, 10800, 11100, 11400, 11700, 12000, 12300, 12600, 12900, 13200, 13500, 13800, 14100, 14400, 14700, 15000, 15300, 15600, 15900, 16200, 16500, 16800, 17100, 17400, 17700, 18000, 18300, 18600, 18900, 19200, 19500, 19800, 20100, 20400, 20700, 21000, 21300, 21600, 21900, 22200, 22500, 22800, 23100, 23400, 23700, 24000, 24300, 24600, 24900, 25200, 25500, 25800, 26100, 26400, 26700, 27000, 27300, 27600, 27900, 28200, 28500, 28800, 29100, 29400, 29700, 30000, 30300, 30600, 30900, 31200, 31500, 31800, 32100, 32400, 32700, 33000, 33300, 33600, 33900, 34200, 34500, 34800, 35100, 35400, 35700, 36000, 36300, 36600, 36900, 37200, 37500, 37800, 38100, 38400, 38700, 39000, 39300, 39600, 39900, 40200, 40500, 40800, 41100, 41400, 41700, 42000, 42300, 42600, 42900, 43200, 43500, 43800, 44100, 44400, 44700, 45000, 45300, 45600, 45900, 46200, 46500, 46800, 47100, 47400, 47700, 48000, 48300, 48600, 48900, 49200, 49500, 49800, 50100, 50400, 50700, 51000, 51300, 51600, 51900, 52200, 52500, 52800, 53100, 53400, 53700, 54000, 54300, 54600, 54900, 55200, 55500, 55800, 56100, 56400, 56700, 57000, 57300, 57600, 57900, 58200, 58500, 58800, 59100, 59400, 59700, 60000, 60300, 60600, 60900, 61200, 61500, 61800, 62100, 62400, 62700, 63000, 63300, 63600, 63900, 64200, 64500, 64800, 65100, 65400, 65700, 66000, 66300, 66600, 66900, 67200, 67500, 67800, 68100, 68400, 68700, 69000, 69300, 69600, 69900, 70200, 70500, 70800, 71100, 71400, 71700, 72000, 72300, 72600, 72900, 73200, 73500, 73800, 74100, 74400, 74700, 75000, 75300, 75600, 75900, 76200, 76500, 76800, 77100, 77400, 77700, 78000, 78300, 78600, 78900, 79200, 79500, 79800, 80100, 80400, 80700, 81000, 81300, 81600, 81900, 82200, 82500, 82800]
#
# 17 21377 42780 8906
# range(21377, 82966)
# [21600, 21900, 22200, 22500, 22800, 23100, 23400, 23700, 24000, 24300, 24600, 24900, 25200, 25500, 25800, 26100, 26400, 26700, 27000, 27300, 27600, 27900, 28200, 28500, 28800, 29100, 29400, 29700, 30000, 30300, 30600, 30900, 31200, 31500, 31800, 32100, 32400, 32700, 33000, 33300, 33600, 33900, 34200, 34500, 34800, 35100, 35400, 35700, 36000, 36300, 36600, 36900, 37200, 37500, 37800, 38100, 38400, 38700, 39000, 39300, 39600, 39900, 40200, 40500, 40800, 41100, 41400, 41700, 42000, 42300, 42600, 42900, 43200, 43500, 43800, 44100, 44400, 44700, 45000, 45300, 45600, 45900, 46200, 46500, 46800, 47100, 47400, 47700, 48000, 48300, 48600, 48900, 49200, 49500, 49800, 50100, 50400, 50700, 51000, 51300, 51600, 51900, 52200, 52500, 52800, 53100, 53400, 53700, 54000, 54300, 54600, 54900, 55200, 55500, 55800, 56100, 56400, 56700, 57000, 57300, 57600, 57900, 58200, 58500, 58800, 59100, 59400, 59700, 60000, 60300, 60600, 60900, 61200, 61500, 61800, 62100, 62400, 62700, 63000, 63300, 63600, 63900, 64200, 64500, 64800, 65100, 65400, 65700, 66000, 66300, 66600, 66900, 67200, 67500, 67800, 68100, 68400, 68700, 69000, 69300, 69600, 69900, 70200, 70500, 70800, 71100, 71400, 71700, 72000, 72300, 72600, 72900, 73200, 73500, 73800, 74100, 74400, 74700, 75000, 75300, 75600, 75900, 76200, 76500, 76800, 77100, 77400, 77700, 78000, 78300, 78600, 78900, 79200, 79500, 79800, 80100, 80400, 80700, 81000, 81300, 81600, 81900, 82200, 82500, 82800]
#
# 18 13641 74594 10769
# range(13641, 82966)
# [13800, 14100, 14400, 14700, 15000, 15300, 15600, 15900, 16200, 16500, 16800, 17100, 17400, 17700, 18000, 18300, 18600, 18900, 19200, 19500, 19800, 20100, 20400, 20700, 21000, 21300, 21600, 21900, 22200, 22500, 22800, 23100, 23400, 23700, 24000, 24300, 24600, 24900, 25200, 25500, 25800, 26100, 26400, 26700, 27000, 27300, 27600, 27900, 28200, 28500, 28800, 29100, 29400, 29700, 30000, 30300, 30600, 30900, 31200, 31500, 31800, 32100, 32400, 32700, 33000, 33300, 33600, 33900, 34200, 34500, 34800, 35100, 35400, 35700, 36000, 36300, 36600, 36900, 37200, 37500, 37800, 38100, 38400, 38700, 39000, 39300, 39600, 39900, 40200, 40500, 40800, 41100, 41400, 41700, 42000, 42300, 42600, 42900, 43200, 43500, 43800, 44100, 44400, 44700, 45000, 45300, 45600, 45900, 46200, 46500, 46800, 47100, 47400, 47700, 48000, 48300, 48600, 48900, 49200, 49500, 49800, 50100, 50400, 50700, 51000, 51300, 51600, 51900, 52200, 52500, 52800, 53100, 53400, 53700, 54000, 54300, 54600, 54900, 55200, 55500, 55800, 56100, 56400, 56700, 57000, 57300, 57600, 57900, 58200, 58500, 58800, 59100, 59400, 59700, 60000, 60300, 60600, 60900, 61200, 61500, 61800, 62100, 62400, 62700, 63000, 63300, 63600, 63900, 64200, 64500, 64800, 65100, 65400, 65700, 66000, 66300, 66600, 66900, 67200, 67500, 67800, 68100, 68400, 68700, 69000, 69300, 69600, 69900, 70200, 70500, 70800, 71100, 71400, 71700, 72000, 72300, 72600, 72900, 73200, 73500, 73800, 74100, 74400, 74700, 75000, 75300, 75600, 75900, 76200, 76500, 76800, 77100, 77400, 77700, 78000, 78300, 78600, 78900, 79200, 79500, 79800, 80100, 80400, 80700, 81000, 81300, 81600, 81900, 82200, 82500, 82800]
#
# 19 75174 82965 4405
# range(75174, 82966)
# [75300, 75600, 75900, 76200, 76500, 76800, 77100, 77400, 77700, 78000, 78300, 78600, 78900, 79200, 79500, 79800, 80100, 80400, 80700, 81000, 81300, 81600, 81900, 82200, 82500, 82800]
#
# HELLO

# %%
aikt = {}

for slice_num, slice_id in enumerate(slices):
    slice = slices[slice_id]
    for segment in range(slice["duration"]):
        win_id = slice["start"] + segment
        if win_id in aikt:
            aikt[win_id].append(slice_num)
        else:
            aikt[win_id] = [slice_num]

# for k in sorted(aikt.keys()):
    # print(k, aikt[k])

# %% [markdown]
# ### Build Model

# %%
def build_model(yik, aikt):
    m = Model("Test Schedule")

    requestLocations = tuplelist()
    scheduled_vars = []

    for r in yik:
        var = m.addVar(vtype=GRB.BINARY, name=str(r[0]))
        scheduled_vars.append(var)
        request_locations.append((r[0], r[1], r[2], r[3], var)) # resID, start_w_idx, priority, resource, isScheduled?
    m.update()

    # Constraint 4: Each request only scheduled once
    for rid in requests:
        match = requestLocations.select(rid, '*', '*', '*', '*', '*')
        nscheduled = quicksum([isScheduled for reqid, wnum, priority, resource, isScheduled in match])
        m.addConstr(nscheduled <= 1, f'one_per_reqid_constraint_{rid}')
    m.update()

    # Constraint 3: Each timeslice should only have one request in it
    for s in aikt.keys():
        match = tuplelist()
        for timeslice in aikt[s]:
            match.append(request_locations[timeslice])
        nscheduled = quicksum(isScheduled for reqid, winidx, priority, resource, isScheduled in match)
        m.addConstr(nscheduled <= 1, f"one_per_slice_constrain_{s}")

    objective = quicksum([isScheduled * (priority + 0.1/(wnum+1.0)) for req, start, priority, resource, isScheduled in requestLocations])

    m.setObjective(objective)
    m.modelSense(GRB.MAXIMIZE)

    # Implement a timelimit? (Do I actually want to do this?)
    if timelimit > 0:
        m.params.timeLimit = timelimit

    # Set the tolerance of the solution
    m.params.MIPGap = 0.01

    # Set the Method of solving the root relaxation of the MIPs model to concurrent
    m.params.Method = 3

    m.update()

    m.write("test_model.mps")

# %% [markdown]
# #### Load Model

# %%
def load_model(model_name="test_model.mps"):
    model = gurobi_read_model(model_name)
    return model

# %% [markdown]
# ## Input Parameters
#
# ### Set request-generation parameters

# %%
num_requests = 20
request_min_length = 30
request_max_length = 60*60*3
priority_min = 1
priority_max = 10

# %% [markdown]
# ### Set up resources and availability windows TODO

# %%
resources = ["t1"] #,"t2", "t3"
timeslices = [i for i in range(START_TIME, START_TIME + horizon, slice_size)]
print(len(timeslices))
# timeslices = [i for i in range(300)]
print(resources)
print(timeslices)
# Out:
# 288
# ['t1']
# [0, 300, 600, 900, 1200, 1500, 1800, 2100, 2400, 2700, 3000, 3300, 3600, 3900, 4200, 4500, 4800, 5100, 5400, 5700, 6000, 6300, 6600, 6900, 7200, 7500, 7800, 8100, 8400, 8700, 9000, 9300, 9600, 9900, 10200, 10500, 10800, 11100, 11400, 11700, 12000, 12300, 12600, 12900, 13200, 13500, 13800, 14100, 14400, 14700, 15000, 15300, 15600, 15900, 16200, 16500, 16800, 17100, 17400, 17700, 18000, 18300, 18600, 18900, 19200, 19500, 19800, 20100, 20400, 20700, 21000, 21300, 21600, 21900, 22200, 22500, 22800, 23100, 23400, 23700, 24000, 24300, 24600, 24900, 25200, 25500, 25800, 26100, 26400, 26700, 27000, 27300, 27600, 27900, 28200, 28500, 28800, 29100, 29400, 29700, 30000, 30300, 30600, 30900, 31200, 31500, 31800, 32100, 32400, 32700, 33000, 33300, 33600, 33900, 34200, 34500, 34800, 35100, 35400, 35700, 36000, 36300, 36600, 36900, 37200, 37500, 37800, 38100, 38400, 38700, 39000, 39300, 39600, 39900, 40200, 40500, 40800, 41100, 41400, 41700, 42000, 42300, 42600, 42900, 43200, 43500, 43800, 44100, 44400, 44700, 45000, 45300, 45600, 45900, 46200, 46500, 46800, 47100, 47400, 47700, 48000, 48300, 48600, 48900, 49200, 49500, 49800, 50100, 50400, 50700, 51000, 51300, 51600, 51900, 52200, 52500, 52800, 53100, 53400, 53700, 54000, 54300, 54600, 54900, 55200, 55500, 55800, 56100, 56400, 56700, 57000, 57300, 57600, 57900, 58200, 58500, 58800, 59100, 59400, 59700, 60000, 60300, 60600, 60900, 61200, 61500, 61800, 62100, 62400, 62700, 63000, 63300, 63600, 63900, 64200, 64500, 64800, 65100, 65400, 65700, 66000, 66300, 66600, 66900, 67200, 67500, 67800, 68100, 68400, 68700, 69000, 69300, 69600, 69900, 70200, 70500, 70800, 71100, 71400, 71700, 72000, 72300, 72600, 72900, 73200, 73500, 73800, 74100, 74400, 74700, 75000, 75300, 75600, 75900, 76200, 76500, 76800, 77100, 77400, 77700, 78000, 78300, 78600, 78900, 79200, 79500, 79800, 80100, 80400, 80700, 81000, 81300, 81600, 81900, 82200, 82500, 82800, 83100, 83400, 83700, 84000, 84300, 84600, 84900, 85200, 85500, 85800, 86100]

# %% [markdown]
# ### Generate Observation Requests (Randomly)

# %%
# Generate random requests
requests = {}

for i in range(num_requests):
    # NOTE: Need to come up with a method of cadencing these, as an observing window cannot exist continuously for 3 days...
    # Also it could be for a couple of hours per night, as opposed to just one long stretch.
    
    t1 = random.randint(START_TIME, START_TIME + horizon)
    t2 = random.randint(START_TIME, START_TIME + horizon)
    start = min([t1, t2])
    end = max([t1, t2])
    
    length = min(random.randint(request_min_length, request_max_length), end-start)
    
    priority = random.randint(priority_min, priority_max)
    
    requests[i] = {
            "window_start": start,
            "window_end": end,
            "length": length,
            "priority": priority
        }

for r in requests.items():
    print(r)
# Out:
# (0, {'window_start': 31190, 'window_end': 77678, 'length': 8946, 'priority': 3})
# (1, {'window_start': 48490, 'window_end': 79157, 'length': 7796, 'priority': 10})
# (2, {'window_start': 8588, 'window_end': 79377, 'length': 245, 'priority': 8})
# (3, {'window_start': 33994, 'window_end': 72192, 'length': 3869, 'priority': 4})
# (4, {'window_start': 61638, 'window_end': 70906, 'length': 9035, 'priority': 8})
# (5, {'window_start': 52053, 'window_end': 83763, 'length': 2497, 'priority': 4})
# (6, {'window_start': 19873, 'window_end': 83212, 'length': 8601, 'priority': 7})
# (7, {'window_start': 1985, 'window_end': 8392, 'length': 2641, 'priority': 10})
# (8, {'window_start': 5608, 'window_end': 39487, 'length': 538, 'priority': 5})
# (9, {'window_start': 61964, 'window_end': 77955, 'length': 6380, 'priority': 7})
# (10, {'window_start': 51768, 'window_end': 75616, 'length': 7314, 'priority': 3})
# (11, {'window_start': 12773, 'window_end': 47909, 'length': 617, 'priority': 3})
# (12, {'window_start': 28440, 'window_end': 64865, 'length': 4256, 'priority': 7})
# (13, {'window_start': 39456, 'window_end': 82136, 'length': 6930, 'priority': 9})
# (14, {'window_start': 50576, 'window_end': 75238, 'length': 5779, 'priority': 9})
# (15, {'window_start': 53421, 'window_end': 76686, 'length': 9602, 'priority': 4})
# (16, {'window_start': 3756, 'window_end': 44140, 'length': 4612, 'priority': 10})
# (17, {'window_start': 21377, 'window_end': 42780, 'length': 8906, 'priority': 10})
# (18, {'window_start': 13641, 'window_end': 74594, 'length': 10769, 'priority': 4})
# (19, {'window_start': 75174, 'window_end': 82965, 'length': 4405, 'priority': 5})

# %% [markdown]
# ## Build Model (OUTDATED)

# %%
m = Model("Test Schedule")

# %%
requestLocations = tuplelist()
scheduled_vars = []

for r in yik:
    

for r_name, r in slices.items():
    var = m.addVar(vtype=GRB.BINARY, name=str(r_name))
    scheduled_vars.append(var)
    requestLocations.append((r["rid"], r["start"], r["priority"], r["resource"], var))

m.update()

# %%
# I DON'T KNOW WHY WE NEED THIS ONE
# for i, r in enumerate(slices):
    # print(r)
    # scheduled_vars[i].start = r["start"]
# m.update()

# %%
# Constraint 1: One-of (only schedule one of these)
# Are we going to include these constraints in our final model? If there's no special cases, then they just turn into 
# Constraint 4 (which is why there is a skip_constraint2 flag).

# %%
# # Constraint 2: And (only schedule if they can ALL be scheduled)
# # I'm going to use this to ensure that all of an observation is schedule

# NOTE: Not what this is used for. Each Request/Resource/Start has a unique IsScheduled variable, not each timeslice.

# Use this to schedule cadenced observations? And what does that mean if one of an AND condition has already been observed?
# Are the rest of the observations now fixed in place?
# Maybe this is too complicated to inject in the first run, especially as I don't  know how LCO implements these things - I don't know what observation
# requests get tagged with the AND or OR constraints (1 and 2), and how they are handled internally once part of the AND condition is fulfilled.

# %%
# Constraint 4: Each request only scheduled once
for rid in requests:
    match = requestLocations.select(rid, '*', '*', '*', '*', '*')
    nscheduled = quicksum([isScheduled for reqid, wnum, priority, resource, isScheduled in match])
    m.addConstr(nscheduled <= 1, f'one_per_reqid_constraint_{rid}')
m.update()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 # Constraint 4: Each request only scheduled once
#       2 for rid in requests:
# ----> 3     match = requestLocations.select(rid, '*', '*', '*', '*', '*')
#       4     nscheduled = quicksum([isScheduled for reqid, wnum, priority, resource, isScheduled in match])
#       5     m.addConstr(nscheduled <= 1, f'one_per_reqid_constraint_{rid}')
#
# NameError: name 'requestLocations' is not defined

# %%
# Constraint 3: Each timeslice should only have one request in it
for r in resource_slices:
    for wnum in resource_slices[r]:
        match = requestLocations.select('*', wnum, '*', r, '*', '*')
        if len(match) == 0:
            continue
        nscheduled = quicksum(isScheduled for i, w, p, r, isScheduled in match)
        m.addConstr(nscheduled <= 1, f'one_per_slice_constraint_{r}_{wnum}')
m.update()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 # Constraint 3: Each timeslice should only have one request in it
#       2 for r in resource_slices:
# ----> 3     for wnum in resource_slices[r]:
#       4         match = requestLocations.select('*', wnum, '*', r, '*', '*')
#       5         if len(match) == 0:
#
# TypeError: 'int' object is not iterable

# %%
for s in aikt.keys():
    match = tuplelist()
    for slice in aikt[s]:
        match.append(requestLocations[slice])
        print(match)
    nscheduled = quicksum(isScheduled for rid, winidx, priority, resource, isScheduled in match)
    m.addConstr(nscheduled <= 1, 'one_per_slice_constraint_' + s)
# Out:
# <gurobi.tuplelist (1 tuples, 5 values each):
#  ( 0 , 5 , 5 , t1 , <gurobi.Var TEL-t1_ID-0_ST-5> )
# >
# <gurobi.tuplelist (2 tuples, 5 values each):
#  ( 0 , 5 , 5 , t1 , <gurobi.Var TEL-t1_ID-0_ST-5> )
#  ( 1 , 5 , 4 , t1 , <gurobi.Var TEL-t1_ID-1_ST-5> )
# >
# <gurobi.tuplelist (3 tuples, 5 values each):
#  ( 0 , 5 , 5 , t1 , <gurobi.Var TEL-t1_ID-0_ST-5> )
#  ( 1 , 5 , 4 , t1 , <gurobi.Var TEL-t1_ID-1_ST-5> )
#  ( 2 , 5 , 2 , t1 , <gurobi.Var TEL-t1_ID-2_ST-5> )
# >
# <gurobi.tuplelist (4 tuples, 5 values each):
#  ( 0 , 5 , 5 , t1 , <gurobi.Var TEL-t1_ID-0_ST-5> )
#  ( 1 , 5 , 4 , t1 , <gurobi.Var TEL-t1_ID-1_ST-5> )
#  ( 2 , 5 , 2 , t1 , <gurobi.Var TEL-t1_ID-2_ST-5> )
#  ( 4 , 5 , 2 , t1 , <gurobi.Var TEL-t1_ID-4_ST-5> )
# >
# <gurobi.tuplelist (5 tuples, 5 values each):
#  ( 0 , 5 , 5 , t1 , <gurobi.Var TEL-t1_ID-0_ST-5> )
#  ( 1 , 5 , 4 , t1 , <gurobi.Var TEL-t1_ID-1_ST-5> )
#  ( 2 , 5 , 2 , t1 , <gurobi.Var TEL-t1_ID-2_ST-5> )
#  ( 4 , 5 , 2 , t1 , <gurobi.Var TEL-t1_ID-4_ST-5> )
#  ( 6 , 5 , 1 , t1 , <gurobi.Var TEL-t1_ID-6_ST-5> )
# >
# <gurobi.tuplelist (6 tuples, 5 values each):
#  ( 0 , 5 , 5 , t1 , <gurobi.Var TEL-t1_ID-0_ST-5> )
#  ( 1 , 5 , 4 , t1 , <gurobi.Var TEL-t1_ID-1_ST-5> )
#  ( 2 , 5 , 2 , t1 , <gurobi.Var TEL-t1_ID-2_ST-5> )
#  ( 4 , 5 , 2 , t1 , <gurobi.Var TEL-t1_ID-4_ST-5> )
#  ( 6 , 5 , 1 , t1 , <gurobi.Var TEL-t1_ID-6_ST-5> )
#  ( 7 , 4 , 4 , t1 , <gurobi.Var TEL-t1_ID-7_ST-4> )
# >
# <gurobi.tuplelist (7 tuples, 5 values each):
#  ( 0 , 5 , 5 , t1 , <gurobi.Var TEL-t1_ID-0_ST-5> )
#  ( 1 , 5 , 4 , t1 , <gurobi.Var TEL-t1_ID-1_ST-5> )
#  ( 2 , 5 , 2 , t1 , <gurobi.Var TEL-t1_ID-2_ST-5> )
#  ( 4 , 5 , 2 , t1 , <gurobi.Var TEL-t1_ID-4_ST-5> )
#  ( 6 , 5 , 1 , t1 , <gurobi.Var TEL-t1_ID-6_ST-5> )
#  ( 7 , 4 , 4 , t1 , <gurobi.Var TEL-t1_ID-7_ST-4> )
#  ( 7 , 5 , 4 , t1 , <gurobi.Var TEL-t1_ID-7_ST-5> )
# >
# <gurobi.tuplelist (1 tuples, 5 values each):
#  ( 0 , 5 , 5 , t1 , <gurobi.Var TEL-t1_ID-0_ST-5> )
# >
# <gurobi.tuplelist (2 tuples, 5 values each):
#  ( 0 , 5 , 5 , t1 , <gurobi.Var TEL-t1_ID-0_ST-5> )
#  ( 0 , 6 , 5 , t1 , <gurobi.Var TEL-t1_ID-0_ST-6> )
# >
# <gurobi.tuplelist (3 tuples, 5 values each):
#  ( 0 , 5 , 5 , t1 , <gurobi.Var TEL-t1_ID-0_ST-5> )
#  ( 0 , 6 , 5 , t1 , <gurobi.Var TEL-t1_ID-0_ST-6> )
#  ( 1 , 6 , 4 , t1 , <gurobi.Var TEL-t1_ID-1_ST-6> )
# >
# <gurobi.tuplelist (4 tuples, 5 values each):
#  ( 0 , 5 , 5 , t1 , <gurobi.Var TEL-t1_ID-0_ST-5> )
#  ( 0 , 6 , 5 , t1 , <gurobi.Var TEL-t1_ID-0_ST-6> )
#  ( 1 , 6 , 4 , t1 , <gurobi.Var TEL-t1_ID-1_ST-6> )
#  ( 2 , 6 , 2 , t1 , <gurobi.Var TEL-t1_ID-2_ST-6> )
# >
# <gurobi.tuplelist (5 tuples, 5 values each):
#  ( 0 , 5 , 5 , t1 , <gurobi.Var TEL-t1_ID-0_ST-5> )
#  ( 0 , 6 , 5 , t1 , <gurobi.Var TEL-t1_ID-0_ST-6> )
#  ( 1 , 6 , 4 , t1 , <gurobi.Var TEL-t1_ID-1_ST-6> )
#  ( 2 , 6 , 2 , t1 , <gurobi.Var TEL-t1_ID-2_ST-6> )
#  ( 4 , 6 , 2 , t1 , <gurobi.Var TEL-t1_ID-4_ST-6> )
# >
# <gurobi.tuplelist (6 tuples, 5 values each):
#  ( 0 , 5 , 5 , t1 , <gurobi.Var TEL-t1_ID-0_ST-5> )
#  ( 0 , 6 , 5 , t1 , <gurobi.Var TEL-t1_ID-0_ST-6> )
#  ( 1 , 6 , 4 , t1 , <gurobi.Var TEL-t1_ID-1_ST-6> )
#  ( 2 , 6 , 2 , t1 , <gurobi.Var TEL-t1_ID-2_ST-6> )
#  ( 4 , 6 , 2 , t1 , <gurobi.Var TEL-t1_ID-4_ST-6> )
#  ( 5 , 6 , 1 , t1 , <gurobi.Var TEL-t1_ID-5_ST-6> )
# >
# <gurobi.tuplelist (7 tuples, 5 values each):
#  ( 0 , 5 , 5 , t1 , <gurobi.Var TEL-t1_ID-0_ST-5> )
#  ( 0 , 6 , 5 , t1 , <gurobi.Var TEL-t1_ID-0_ST-6> )
#  ( 1 , 6 , 4 , t1 , <gurobi.Var TEL-t1_ID-1_ST-6> )
#  ( 2 , 6 , 2 , t1 , <gurobi.Var TEL-t1_ID-2_ST-6> )
#  ( 4 , 6 , 2 , t1 , <gurobi.Var TEL-t1_ID-4_ST-6> )
#  ( 5 , 6 , 1 , t1 , <gurobi.Var TEL-t1_ID-5_ST-6> )
#  ( 6 , 6 , 1 , t1 , <gurobi.Var TEL-t1_ID-6_ST-6> )
# >
# <gurobi.tuplelist (8 tuples, 5 values each):
#  ( 0 , 5 , 5 , t1 , <gurobi.Var TEL-t1_ID-0_ST-5> )
#  ( 0 , 6 , 5 , t1 , <gurobi.Var TEL-t1_ID-0_ST-6> )
#  ( 1 , 6 , 4 , t1 , <gurobi.Var TEL-t1_ID-1_ST-6> )
#  ( 2 , 6 , 2 , t1 , <gurobi.Var TEL-t1_ID-2_ST-6> )
#  ( 4 , 6 , 2 , t1 , <gurobi.Var TEL-t1_ID-4_ST-6> )
#  ( 5 , 6 , 1 , t1 , <gurobi.Var TEL-t1_ID-5_ST-6> )
#  ( 6 , 6 , 1 , t1 , <gurobi.Var TEL-t1_ID-6_ST-6> )
#  ( 7 , 5 , 4 , t1 , <gurobi.Var TEL-t1_ID-7_ST-5> )
# >
# <gurobi.tuplelist (9 tuples, 5 values each):
#  ( 0 , 5 , 5 , t1 , <gurobi.Var TEL-t1_ID-0_ST-5> )
#  ( 0 , 6 , 5 , t1 , <gurobi.Var TEL-t1_ID-0_ST-6> )
#  ( 1 , 6 , 4 , t1 , <gurobi.Var TEL-t1_ID-1_ST-6> )
#  ( 2 , 6 , 2 , t1 , <gurobi.Var TEL-t1_ID-2_ST-6> )
#  ( 4 , 6 , 2 , t1 , <gurobi.Var TEL-t1_ID-4_ST-6> )
#  ( 5 , 6 , 1 , t1 , <gurobi.Var TEL-t1_ID-5_ST-6> )
#  ( 6 , 6 , 1 , t1 , <gurobi.Var TEL-t1_ID-6_ST-6> )
#  ( 7 , 5 , 4 , t1 , <gurobi.Var TEL-t1_ID-7_ST-5> )
#  ( 7 , 6 , 4 , t1 , <gurobi.Var TEL-t1_ID-7_ST-6> )
# >
# <gurobi.tuplelist (10 tuples, 5 values each):
#  ( 0 , 5 , 5 , t1 , <gurobi.Var TEL-t1_ID-0_ST-5> )
#  ( 0 , 6 , 5 , t1 , <gurobi.Var TEL-t1_ID-0_ST-6> )
#  ( 1 , 6 , 4 , t1 , <gurobi.Var TEL-t1_ID-1_ST-6> )
#  ( 2 , 6 , 2 , t1 , <gurobi.Var TEL-t1_ID-2_ST-6> )
#  ( 4 , 6 , 2 , t1 , <gurobi.Var TEL-t1_ID-4_ST-6> )
#  ( 5 , 6 , 1 , t1 , <gurobi.Var TEL-t1_ID-5_ST-6> )
#  ( 6 , 6 , 1 , t1 , <gurobi.Var TEL-t1_ID-6_ST-6> )
#  ( 7 , 5 , 4 , t1 , <gurobi.Var TEL-t1_ID-7_ST-5> )
#  ( 7 , 6 , 4 , t1 , <gurobi.Var TEL-t1_ID-7_ST-6> )
#  ( 9 , 6 , 2 , t1 , <gurobi.Var TEL-t1_ID-9_ST-6> )
# >
# <gurobi.tuplelist (1 tuples, 5 values each):
#  ( 0 , 6 , 5 , t1 , <gurobi.Var TEL-t1_ID-0_ST-6> )
# >
# <gurobi.tuplelist (2 tuples, 5 values each):
#  ( 0 , 6 , 5 , t1 , <gurobi.Var TEL-t1_ID-0_ST-6> )
#  ( 1 , 7 , 4 , t1 , <gurobi.Var TEL-t1_ID-1_ST-7> )
# >
# <gurobi.tuplelist (3 tuples, 5 values each):
#  ( 0 , 6 , 5 , t1 , <gurobi.Var TEL-t1_ID-0_ST-6> )
#  ( 1 , 7 , 4 , t1 , <gurobi.Var TEL-t1_ID-1_ST-7> )
#  ( 2 , 7 , 2 , t1 , <gurobi.Var TEL-t1_ID-2_ST-7> )
# >
# <gurobi.tuplelist (4 tuples, 5 values each):
#  ( 0 , 6 , 5 , t1 , <gurobi.Var TEL-t1_ID-0_ST-6> )
#  ( 1 , 7 , 4 , t1 , <gurobi.Var TEL-t1_ID-1_ST-7> )
#  ( 2 , 7 , 2 , t1 , <gurobi.Var TEL-t1_ID-2_ST-7> )
#  ( 3 , 7 , 4 , t1 , <gurobi.Var TEL-t1_ID-3_ST-7> )
# >
# <gurobi.tuplelist (5 tuples, 5 values each):
#  ( 0 , 6 , 5 , t1 , <gurobi.Var TEL-t1_ID-0_ST-6> )
#  ( 1 , 7 , 4 , t1 , <gurobi.Var TEL-t1_ID-1_ST-7> )
#  ( 2 , 7 , 2 , t1 , <gurobi.Var TEL-t1_ID-2_ST-7> )
#  ( 3 , 7 , 4 , t1 , <gurobi.Var TEL-t1_ID-3_ST-7> )
#  ( 4 , 7 , 2 , t1 , <gurobi.Var TEL-t1_ID-4_ST-7> )
# >
# <gurobi.tuplelist (6 tuples, 5 values each):
#  ( 0 , 6 , 5 , t1 , <gurobi.Var TEL-t1_ID-0_ST-6> )
#  ( 1 , 7 , 4 , t1 , <gurobi.Var TEL-t1_ID-1_ST-7> )
#  ( 2 , 7 , 2 , t1 , <gurobi.Var TEL-t1_ID-2_ST-7> )
#  ( 3 , 7 , 4 , t1 , <gurobi.Var TEL-t1_ID-3_ST-7> )
#  ( 4 , 7 , 2 , t1 , <gurobi.Var TEL-t1_ID-4_ST-7> )
#  ( 5 , 6 , 1 , t1 , <gurobi.Var TEL-t1_ID-5_ST-6> )
# >
# <gurobi.tuplelist (7 tuples, 5 values each):
#  ( 0 , 6 , 5 , t1 , <gurobi.Var TEL-t1_ID-0_ST-6> )
#  ( 1 , 7 , 4 , t1 , <gurobi.Var TEL-t1_ID-1_ST-7> )
#  ( 2 , 7 , 2 , t1 , <gurobi.Var TEL-t1_ID-2_ST-7> )
#  ( 3 , 7 , 4 , t1 , <gurobi.Var TEL-t1_ID-3_ST-7> )
#  ( 4 , 7 , 2 , t1 , <gurobi.Var TEL-t1_ID-4_ST-7> )
#  ( 5 , 6 , 1 , t1 , <gurobi.Var TEL-t1_ID-5_ST-6> )
#  ( 6 , 7 , 1 , t1 , <gurobi.Var TEL-t1_ID-6_ST-7> )
# >
# <gurobi.tuplelist (8 tuples, 5 values each):
#  ( 0 , 6 , 5 , t1 , <gurobi.Var TEL-t1_ID-0_ST-6> )
#  ( 1 , 7 , 4 , t1 , <gurobi.Var TEL-t1_ID-1_ST-7> )
#  ( 2 , 7 , 2 , t1 , <gurobi.Var TEL-t1_ID-2_ST-7> )
#  ( 3 , 7 , 4 , t1 , <gurobi.Var TEL-t1_ID-3_ST-7> )
#  ( 4 , 7 , 2 , t1 , <gurobi.Var TEL-t1_ID-4_ST-7> )
#  ( 5 , 6 , 1 , t1 , <gurobi.Var TEL-t1_ID-5_ST-6> )
#  ( 6 , 7 , 1 , t1 , <gurobi.Var TEL-t1_ID-6_ST-7> )
#  ( 7 , 6 , 4 , t1 , <gurobi.Var TEL-t1_ID-7_ST-6> )
# >
# <gurobi.tuplelist (9 tuples, 5 values each):
#  ( 0 , 6 , 5 , t1 , <gurobi.Var TEL-t1_ID-0_ST-6> )
#  ( 1 , 7 , 4 , t1 , <gurobi.Var TEL-t1_ID-1_ST-7> )
#  ( 2 , 7 , 2 , t1 , <gurobi.Var TEL-t1_ID-2_ST-7> )
#  ( 3 , 7 , 4 , t1 , <gurobi.Var TEL-t1_ID-3_ST-7> )
#  ( 4 , 7 , 2 , t1 , <gurobi.Var TEL-t1_ID-4_ST-7> )
#  ( 5 , 6 , 1 , t1 , <gurobi.Var TEL-t1_ID-5_ST-6> )
#  ( 6 , 7 , 1 , t1 , <gurobi.Var TEL-t1_ID-6_ST-7> )
#  ( 7 , 6 , 4 , t1 , <gurobi.Var TEL-t1_ID-7_ST-6> )
#  ( 9 , 6 , 2 , t1 , <gurobi.Var TEL-t1_ID-9_ST-6> )
# >
# <gurobi.tuplelist (1 tuples, 5 values each):
#  ( 1 , 1 , 4 , t1 , <gurobi.Var TEL-t1_ID-1_ST-1> )
# >
# <gurobi.tuplelist (2 tuples, 5 values each):
#  ( 1 , 1 , 4 , t1 , <gurobi.Var TEL-t1_ID-1_ST-1> )
#  ( 6 , 1 , 1 , t1 , <gurobi.Var TEL-t1_ID-6_ST-1> )
# >
# <gurobi.tuplelist (3 tuples, 5 values each):
#  ( 1 , 1 , 4 , t1 , <gurobi.Var TEL-t1_ID-1_ST-1> )
#  ( 6 , 1 , 1 , t1 , <gurobi.Var TEL-t1_ID-6_ST-1> )
#  ( 7 , 0 , 4 , t1 , <gurobi.Var TEL-t1_ID-7_ST-0> )
# >
# <gurobi.tuplelist (1 tuples, 5 values each):
#  ( 1 , 4 , 4 , t1 , <gurobi.Var TEL-t1_ID-1_ST-4> )
# >
# <gurobi.tuplelist (2 tuples, 5 values each):
#  ( 1 , 4 , 4 , t1 , <gurobi.Var TEL-t1_ID-1_ST-4> )
#  ( 2 , 4 , 2 , t1 , <gurobi.Var TEL-t1_ID-2_ST-4> )
# >
# <gurobi.tuplelist (3 tuples, 5 values each):
#  ( 1 , 4 , 4 , t1 , <gurobi.Var TEL-t1_ID-1_ST-4> )
#  ( 2 , 4 , 2 , t1 , <gurobi.Var TEL-t1_ID-2_ST-4> )
#  ( 4 , 4 , 2 , t1 , <gurobi.Var TEL-t1_ID-4_ST-4> )
# >
# <gurobi.tuplelist (4 tuples, 5 values each):
#  ( 1 , 4 , 4 , t1 , <gurobi.Var TEL-t1_ID-1_ST-4> )
#  ( 2 , 4 , 2 , t1 , <gurobi.Var TEL-t1_ID-2_ST-4> )
#  ( 4 , 4 , 2 , t1 , <gurobi.Var TEL-t1_ID-4_ST-4> )
#  ( 6 , 4 , 1 , t1 , <gurobi.Var TEL-t1_ID-6_ST-4> )
# >
# <gurobi.tuplelist (5 tuples, 5 values each):
#  ( 1 , 4 , 4 , t1 , <gurobi.Var TEL-t1_ID-1_ST-4> )
#  ( 2 , 4 , 2 , t1 , <gurobi.Var TEL-t1_ID-2_ST-4> )
#  ( 4 , 4 , 2 , t1 , <gurobi.Var TEL-t1_ID-4_ST-4> )
#  ( 6 , 4 , 1 , t1 , <gurobi.Var TEL-t1_ID-6_ST-4> )
#  ( 7 , 4 , 4 , t1 , <gurobi.Var TEL-t1_ID-7_ST-4> )
# >
# <gurobi.tuplelist (1 tuples, 5 values each):
#  ( 1 , 9 , 4 , t1 , <gurobi.Var TEL-t1_ID-1_ST-9> )
# >
# <gurobi.tuplelist (2 tuples, 5 values each):
#  ( 1 , 9 , 4 , t1 , <gurobi.Var TEL-t1_ID-1_ST-9> )
#  ( 2 , 9 , 2 , t1 , <gurobi.Var TEL-t1_ID-2_ST-9> )
# >
# <gurobi.tuplelist (3 tuples, 5 values each):
#  ( 1 , 9 , 4 , t1 , <gurobi.Var TEL-t1_ID-1_ST-9> )
#  ( 2 , 9 , 2 , t1 , <gurobi.Var TEL-t1_ID-2_ST-9> )
#  ( 3 , 9 , 4 , t1 , <gurobi.Var TEL-t1_ID-3_ST-9> )
# >
# <gurobi.tuplelist (4 tuples, 5 values each):
#  ( 1 , 9 , 4 , t1 , <gurobi.Var TEL-t1_ID-1_ST-9> )
#  ( 2 , 9 , 2 , t1 , <gurobi.Var TEL-t1_ID-2_ST-9> )
#  ( 3 , 9 , 4 , t1 , <gurobi.Var TEL-t1_ID-3_ST-9> )
#  ( 4 , 9 , 2 , t1 , <gurobi.Var TEL-t1_ID-4_ST-9> )
# >
# <gurobi.tuplelist (5 tuples, 5 values each):
#  ( 1 , 9 , 4 , t1 , <gurobi.Var TEL-t1_ID-1_ST-9> )
#  ( 2 , 9 , 2 , t1 , <gurobi.Var TEL-t1_ID-2_ST-9> )
#  ( 3 , 9 , 4 , t1 , <gurobi.Var TEL-t1_ID-3_ST-9> )
#  ( 4 , 9 , 2 , t1 , <gurobi.Var TEL-t1_ID-4_ST-9> )
#  ( 6 , 9 , 1 , t1 , <gurobi.Var TEL-t1_ID-6_ST-9> )
# >
# <gurobi.tuplelist (1 tuples, 5 values each):
#  ( 7 , 0 , 4 , t1 , <gurobi.Var TEL-t1_ID-7_ST-0> )
# >

# %%
objective = quicksum([isScheduled * (priority + 0.1/(wnum+1.0)) for req, start, priority, resource, isScheduled in requestLocations])

# %%
m.setObjective(objective)
m.modelSense = GRB.MAXIMIZE
m.params.MIPGap = 0.01
m.params.Method = 3
m.update()
# Out:
# Set parameter MIPGap to value 0.01
# Set parameter Method to value 3

# %% [markdown]
# ### Write Model to file

# %%
m.write("test_model.mps")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 m.write("test_model.mps")
#
# NameError: name 'm' is not defined

# %% [markdown]
# ### Solve Model

# %%
m.optimize()

# %% [markdown]
# ## Model

# %% [markdown]
# ### Build Model

# %%
build_model(yik, aikt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 build_model(yik, aikt)
#
# NameError: name 'yik' is not defined

# %% [markdown]
# ### Solve Model - Gurobi

# %%
model = load_model()
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-20
# Read MPS format model from file test_model.mps
# Reading time = 0.01 seconds
# Test: 20 rows, 0 columns, 0 nonzeros

# %% [markdown]
# ## Interpret Results

# %%
rxf = [isScheduled.x for rid, start, priority, resource, isScheduled in requestLocations]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 rxf = [isScheduled.x for rid, start, priority, resource, isScheduled in requestLocations]
#
# NameError: name 'requestLocations' is not defined

# %%
print("ID, w, p, reso, s")
for i in range(len(requestLocations)):
    if rxf[i] == 1:
        print(requestLocations[i])
# Out:
# ID, w, p, reso, s
# (1, 207, 4, 't1', <gurobi.Var TEL-t1_ID-1_ST-207 (value 1.0)>)
# (5, 198, 5, 't1', <gurobi.Var TEL-t1_ID-5_ST-198 (value 1.0)>)
# (7, 37, 4, 't3', <gurobi.Var TEL-t3_ID-7_ST-37 (value 1.0)>)
# (8, 96, 2, 't1', <gurobi.Var TEL-t1_ID-8_ST-96 (value 1.0)>)
# (10, 127, 2, 't3', <gurobi.Var TEL-t3_ID-10_ST-127 (value 1.0)>)
# (11, 239, 3, 't1', <gurobi.Var TEL-t1_ID-11_ST-239 (value 1.0)>)
# (19, 249, 3, 't3', <gurobi.Var TEL-t3_ID-19_ST-249 (value 1.0)>)
# (20, 20, 4, 't3', <gurobi.Var TEL-t3_ID-20_ST-20 (value 1.0)>)
# (21, 80, 2, 't1', <gurobi.Var TEL-t1_ID-21_ST-80 (value 1.0)>)
# (22, 193, 4, 't3', <gurobi.Var TEL-t3_ID-22_ST-193 (value 1.0)>)
# (25, 155, 5, 't3', <gurobi.Var TEL-t3_ID-25_ST-155 (value 1.0)>)
# (26, 199, 5, 't2', <gurobi.Var TEL-t2_ID-26_ST-199 (value 1.0)>)
# (27, 179, 4, 't3', <gurobi.Var TEL-t3_ID-27_ST-179 (value 1.0)>)
# (28, 192, 4, 't2', <gurobi.Var TEL-t2_ID-28_ST-192 (value 1.0)>)
# (29, 46, 4, 't3', <gurobi.Var TEL-t3_ID-29_ST-46 (value 1.0)>)
# (30, 165, 1, 't3', <gurobi.Var TEL-t3_ID-30_ST-165 (value 1.0)>)
# (32, 245, 2, 't3', <gurobi.Var TEL-t3_ID-32_ST-245 (value 1.0)>)
# (33, 162, 3, 't3', <gurobi.Var TEL-t3_ID-33_ST-162 (value 1.0)>)
# (35, 15, 5, 't1', <gurobi.Var TEL-t1_ID-35_ST-15 (value 1.0)>)
# (36, 204, 4, 't2', <gurobi.Var TEL-t2_ID-36_ST-204 (value 1.0)>)
# (37, 214, 5, 't2', <gurobi.Var TEL-t2_ID-37_ST-214 (value 1.0)>)
# (40, 180, 4, 't3', <gurobi.Var TEL-t3_ID-40_ST-180 (value 1.0)>)
# (41, 248, 4, 't2', <gurobi.Var TEL-t2_ID-41_ST-248 (value 1.0)>)
# (43, 208, 4, 't2', <gurobi.Var TEL-t2_ID-43_ST-208 (value 1.0)>)
# (45, 182, 3, 't1', <gurobi.Var TEL-t1_ID-45_ST-182 (value 1.0)>)
# (48, 156, 3, 't3', <gurobi.Var TEL-t3_ID-48_ST-156 (value 1.0)>)
# (49, 149, 4, 't2', <gurobi.Var TEL-t2_ID-49_ST-149 (value 1.0)>)
# (50, 124, 2, 't2', <gurobi.Var TEL-t2_ID-50_ST-124 (value 1.0)>)
# (52, 56, 5, 't1', <gurobi.Var TEL-t1_ID-52_ST-56 (value 1.0)>)
# (56, 86, 4, 't3', <gurobi.Var TEL-t3_ID-56_ST-86 (value 1.0)>)
# (58, 117, 2, 't1', <gurobi.Var TEL-t1_ID-58_ST-117 (value 1.0)>)
# (60, 206, 4, 't1', <gurobi.Var TEL-t1_ID-60_ST-206 (value 1.0)>)
# (61, 65, 4, 't2', <gurobi.Var TEL-t2_ID-61_ST-65 (value 1.0)>)
# (62, 182, 5, 't3', <gurobi.Var TEL-t3_ID-62_ST-182 (value 1.0)>)
# (65, 136, 2, 't1', <gurobi.Var TEL-t1_ID-65_ST-136 (value 1.0)>)
# (66, 190, 2, 't3', <gurobi.Var TEL-t3_ID-66_ST-190 (value 1.0)>)
# (68, 79, 2, 't1', <gurobi.Var TEL-t1_ID-68_ST-79 (value 1.0)>)
# (69, 159, 1, 't3', <gurobi.Var TEL-t3_ID-69_ST-159 (value 1.0)>)
# (70, 102, 5, 't1', <gurobi.Var TEL-t1_ID-70_ST-102 (value 1.0)>)
# (71, 183, 5, 't3', <gurobi.Var TEL-t3_ID-71_ST-183 (value 1.0)>)
# (72, 56, 3, 't3', <gurobi.Var TEL-t3_ID-72_ST-56 (value 1.0)>)
# (74, 23, 1, 't1', <gurobi.Var TEL-t1_ID-74_ST-23 (value 1.0)>)
# (76, 206, 1, 't2', <gurobi.Var TEL-t2_ID-76_ST-206 (value 1.0)>)
# (77, 201, 5, 't1', <gurobi.Var TEL-t1_ID-77_ST-201 (value 1.0)>)
# (78, 84, 2, 't1', <gurobi.Var TEL-t1_ID-78_ST-84 (value 1.0)>)
# (81, 35, 5, 't1', <gurobi.Var TEL-t1_ID-81_ST-35 (value 1.0)>)
# (82, 22, 2, 't1', <gurobi.Var TEL-t1_ID-82_ST-22 (value 1.0)>)
# (83, 55, 5, 't1', <gurobi.Var TEL-t1_ID-83_ST-55 (value 1.0)>)
# (85, 246, 4, 't3', <gurobi.Var TEL-t3_ID-85_ST-246 (value 1.0)>)
# (87, 184, 5, 't2', <gurobi.Var TEL-t2_ID-87_ST-184 (value 1.0)>)
# (88, 200, 5, 't1', <gurobi.Var TEL-t1_ID-88_ST-200 (value 1.0)>)
# (89, 126, 4, 't2', <gurobi.Var TEL-t2_ID-89_ST-126 (value 1.0)>)
# (92, 45, 4, 't1', <gurobi.Var TEL-t1_ID-92_ST-45 (value 1.0)>)
# (93, 23, 3, 't2', <gurobi.Var TEL-t2_ID-93_ST-23 (value 1.0)>)
# (95, 39, 3, 't1', <gurobi.Var TEL-t1_ID-95_ST-39 (value 1.0)>)
# (96, 150, 3, 't2', <gurobi.Var TEL-t2_ID-96_ST-150 (value 1.0)>)
# (97, 115, 2, 't1', <gurobi.Var TEL-t1_ID-97_ST-115 (value 1.0)>)
# (98, 132, 3, 't2', <gurobi.Var TEL-t2_ID-98_ST-132 (value 1.0)>)
# (99, 39, 4, 't3', <gurobi.Var TEL-t3_ID-99_ST-39 (value 1.0)>)
# (100, 64, 2, 't2', <gurobi.Var TEL-t2_ID-100_ST-64 (value 1.0)>)
# (101, 244, 1, 't2', <gurobi.Var TEL-t2_ID-101_ST-244 (value 1.0)>)
# (102, 202, 5, 't2', <gurobi.Var TEL-t2_ID-102_ST-202 (value 1.0)>)
# (104, 48, 4, 't3', <gurobi.Var TEL-t3_ID-104_ST-48 (value 1.0)>)
# (105, 196, 3, 't2', <gurobi.Var TEL-t2_ID-105_ST-196 (value 1.0)>)
# (107, 216, 5, 't1', <gurobi.Var TEL-t1_ID-107_ST-216 (value 1.0)>)
# (109, 131, 5, 't2', <gurobi.Var TEL-t2_ID-109_ST-131 (value 1.0)>)
# (110, 2, 5, 't2', <gurobi.Var TEL-t2_ID-110_ST-2 (value 1.0)>)
# (112, 212, 5, 't1', <gurobi.Var TEL-t1_ID-112_ST-212 (value 1.0)>)
# (115, 132, 4, 't3', <gurobi.Var TEL-t3_ID-115_ST-132 (value 1.0)>)
# (117, 84, 4, 't3', <gurobi.Var TEL-t3_ID-117_ST-84 (value 1.0)>)
# (118, 247, 1, 't2', <gurobi.Var TEL-t2_ID-118_ST-247 (value 1.0)>)
# (120, 118, 1, 't3', <gurobi.Var TEL-t3_ID-120_ST-118 (value 1.0)>)
# (123, 24, 4, 't1', <gurobi.Var TEL-t1_ID-123_ST-24 (value 1.0)>)
# (125, 73, 1, 't2', <gurobi.Var TEL-t2_ID-125_ST-73 (value 1.0)>)
# (126, 215, 1, 't1', <gurobi.Var TEL-t1_ID-126_ST-215 (value 1.0)>)
# (128, 178, 5, 't2', <gurobi.Var TEL-t2_ID-128_ST-178 (value 1.0)>)
# (129, 177, 1, 't1', <gurobi.Var TEL-t1_ID-129_ST-177 (value 1.0)>)
# (133, 60, 2, 't3', <gurobi.Var TEL-t3_ID-133_ST-60 (value 1.0)>)
# (135, 239, 4, 't3', <gurobi.Var TEL-t3_ID-135_ST-239 (value 1.0)>)
# (136, 204, 5, 't1', <gurobi.Var TEL-t1_ID-136_ST-204 (value 1.0)>)
# (137, 85, 2, 't3', <gurobi.Var TEL-t3_ID-137_ST-85 (value 1.0)>)
# (138, 222, 1, 't1', <gurobi.Var TEL-t1_ID-138_ST-222 (value 1.0)>)
# (139, 37, 1, 't1', <gurobi.Var TEL-t1_ID-139_ST-37 (value 1.0)>)
# (140, 211, 4, 't1', <gurobi.Var TEL-t1_ID-140_ST-211 (value 1.0)>)
# (142, 163, 4, 't3', <gurobi.Var TEL-t3_ID-142_ST-163 (value 1.0)>)
# (143, 160, 3, 't3', <gurobi.Var TEL-t3_ID-143_ST-160 (value 1.0)>)
# (144, 209, 5, 't1', <gurobi.Var TEL-t1_ID-144_ST-209 (value 1.0)>)
# (145, 87, 4, 't3', <gurobi.Var TEL-t3_ID-145_ST-87 (value 1.0)>)
# (146, 53, 3, 't3', <gurobi.Var TEL-t3_ID-146_ST-53 (value 1.0)>)
# (147, 92, 4, 't3', <gurobi.Var TEL-t3_ID-147_ST-92 (value 1.0)>)
# (150, 50, 1, 't3', <gurobi.Var TEL-t3_ID-150_ST-50 (value 1.0)>)
# (151, 69, 3, 't2', <gurobi.Var TEL-t2_ID-151_ST-69 (value 1.0)>)
# (152, 114, 2, 't1', <gurobi.Var TEL-t1_ID-152_ST-114 (value 1.0)>)
# (156, 14, 3, 't1', <gurobi.Var TEL-t1_ID-156_ST-14 (value 1.0)>)
# (157, 41, 4, 't3', <gurobi.Var TEL-t3_ID-157_ST-41 (value 1.0)>)
# (158, 241, 3, 't2', <gurobi.Var TEL-t2_ID-158_ST-241 (value 1.0)>)
# (159, 231, 5, 't2', <gurobi.Var TEL-t2_ID-159_ST-231 (value 1.0)>)
# (162, 240, 2, 't2', <gurobi.Var TEL-t2_ID-162_ST-240 (value 1.0)>)
# (165, 108, 3, 't1', <gurobi.Var TEL-t1_ID-165_ST-108 (value 1.0)>)
# (166, 91, 2, 't3', <gurobi.Var TEL-t3_ID-166_ST-91 (value 1.0)>)
# (167, 192, 2, 't3', <gurobi.Var TEL-t3_ID-167_ST-192 (value 1.0)>)
# (168, 250, 3, 't2', <gurobi.Var TEL-t2_ID-168_ST-250 (value 1.0)>)
# (169, 194, 5, 't1', <gurobi.Var TEL-t1_ID-169_ST-194 (value 1.0)>)
# (174, 114, 4, 't3', <gurobi.Var TEL-t3_ID-174_ST-114 (value 1.0)>)
# (175, 201, 3, 't2', <gurobi.Var TEL-t2_ID-175_ST-201 (value 1.0)>)
# (178, 199, 5, 't3', <gurobi.Var TEL-t3_ID-178_ST-199 (value 1.0)>)
# (180, 193, 4, 't2', <gurobi.Var TEL-t2_ID-180_ST-193 (value 1.0)>)
# (181, 121, 1, 't3', <gurobi.Var TEL-t3_ID-181_ST-121 (value 1.0)>)
# (183, 145, 3, 't2', <gurobi.Var TEL-t2_ID-183_ST-145 (value 1.0)>)
# (185, 99, 5, 't1', <gurobi.Var TEL-t1_ID-185_ST-99 (value 1.0)>)
# (186, 58, 4, 't2', <gurobi.Var TEL-t2_ID-186_ST-58 (value 1.0)>)
# (188, 69, 5, 't1', <gurobi.Var TEL-t1_ID-188_ST-69 (value 1.0)>)
# (190, 122, 5, 't3', <gurobi.Var TEL-t3_ID-190_ST-122 (value 1.0)>)
# (191, 245, 5, 't2', <gurobi.Var TEL-t2_ID-191_ST-245 (value 1.0)>)
# (194, 21, 4, 't2', <gurobi.Var TEL-t2_ID-194_ST-21 (value 1.0)>)
# (195, 238, 3, 't2', <gurobi.Var TEL-t2_ID-195_ST-238 (value 1.0)>)
# (196, 197, 5, 't1', <gurobi.Var TEL-t1_ID-196_ST-197 (value 1.0)>)
# (199, 238, 5, 't3', <gurobi.Var TEL-t3_ID-199_ST-238 (value 1.0)>)
# (200, 143, 3, 't1', <gurobi.Var TEL-t1_ID-200_ST-143 (value 1.0)>)
# (201, 144, 3, 't2', <gurobi.Var TEL-t2_ID-201_ST-144 (value 1.0)>)
# (203, 226, 1, 't3', <gurobi.Var TEL-t3_ID-203_ST-226 (value 1.0)>)
# (204, 190, 5, 't2', <gurobi.Var TEL-t2_ID-204_ST-190 (value 1.0)>)
# (205, 179, 5, 't2', <gurobi.Var TEL-t2_ID-205_ST-179 (value 1.0)>)
# (206, 221, 3, 't1', <gurobi.Var TEL-t1_ID-206_ST-221 (value 1.0)>)
# (207, 189, 4, 't2', <gurobi.Var TEL-t2_ID-207_ST-189 (value 1.0)>)
# (208, 54, 5, 't1', <gurobi.Var TEL-t1_ID-208_ST-54 (value 1.0)>)
# (209, 81, 3, 't3', <gurobi.Var TEL-t3_ID-209_ST-81 (value 1.0)>)
# (210, 71, 5, 't1', <gurobi.Var TEL-t1_ID-210_ST-71 (value 1.0)>)
# (211, 242, 3, 't2', <gurobi.Var TEL-t2_ID-211_ST-242 (value 1.0)>)
# (212, 153, 5, 't2', <gurobi.Var TEL-t2_ID-212_ST-153 (value 1.0)>)
# (213, 254, 3, 't2', <gurobi.Var TEL-t2_ID-213_ST-254 (value 1.0)>)
# (214, 171, 2, 't1', <gurobi.Var TEL-t1_ID-214_ST-171 (value 1.0)>)
# (216, 210, 5, 't1', <gurobi.Var TEL-t1_ID-216_ST-210 (value 1.0)>)
# (217, 220, 4, 't1', <gurobi.Var TEL-t1_ID-217_ST-220 (value 1.0)>)
# (218, 158, 5, 't3', <gurobi.Var TEL-t3_ID-218_ST-158 (value 1.0)>)
# (219, 168, 3, 't3', <gurobi.Var TEL-t3_ID-219_ST-168 (value 1.0)>)
# (221, 250, 3, 't3', <gurobi.Var TEL-t3_ID-221_ST-250 (value 1.0)>)
# (222, 181, 5, 't3', <gurobi.Var TEL-t3_ID-222_ST-181 (value 1.0)>)
# (224, 118, 4, 't1', <gurobi.Var TEL-t1_ID-224_ST-118 (value 1.0)>)
# (225, 225, 5, 't3', <gurobi.Var TEL-t3_ID-225_ST-225 (value 1.0)>)
# (226, 237, 3, 't2', <gurobi.Var TEL-t2_ID-226_ST-237 (value 1.0)>)
# (227, 183, 3, 't1', <gurobi.Var TEL-t1_ID-227_ST-183 (value 1.0)>)
# (228, 240, 1, 't1', <gurobi.Var TEL-t1_ID-228_ST-240 (value 1.0)>)
# (229, 42, 4, 't3', <gurobi.Var TEL-t3_ID-229_ST-42 (value 1.0)>)
# (231, 0, 3, 't1', <gurobi.Var TEL-t1_ID-231_ST-0 (value 1.0)>)
# (232, 239, 5, 't2', <gurobi.Var TEL-t2_ID-232_ST-239 (value 1.0)>)
# (234, 188, 2, 't3', <gurobi.Var TEL-t3_ID-234_ST-188 (value 1.0)>)
# (235, 209, 5, 't2', <gurobi.Var TEL-t2_ID-235_ST-209 (value 1.0)>)
# (237, 189, 2, 't3', <gurobi.Var TEL-t3_ID-237_ST-189 (value 1.0)>)
# (238, 241, 4, 't1', <gurobi.Var TEL-t1_ID-238_ST-241 (value 1.0)>)
# (239, 214, 2, 't1', <gurobi.Var TEL-t1_ID-239_ST-214 (value 1.0)>)
# (240, 200, 3, 't3', <gurobi.Var TEL-t3_ID-240_ST-200 (value 1.0)>)
# (242, 18, 4, 't1', <gurobi.Var TEL-t1_ID-242_ST-18 (value 1.0)>)
# (243, 188, 4, 't2', <gurobi.Var TEL-t2_ID-243_ST-188 (value 1.0)>)
# (245, 206, 5, 't3', <gurobi.Var TEL-t3_ID-245_ST-206 (value 1.0)>)
# (246, 191, 2, 't3', <gurobi.Var TEL-t3_ID-246_ST-191 (value 1.0)>)
# (247, 62, 5, 't2', <gurobi.Var TEL-t2_ID-247_ST-62 (value 1.0)>)
# (248, 36, 5, 't1', <gurobi.Var TEL-t1_ID-248_ST-36 (value 1.0)>)
# (250, 45, 3, 't3', <gurobi.Var TEL-t3_ID-250_ST-45 (value 1.0)>)
# (251, 212, 5, 't2', <gurobi.Var TEL-t2_ID-251_ST-212 (value 1.0)>)
# (252, 150, 3, 't3', <gurobi.Var TEL-t3_ID-252_ST-150 (value 1.0)>)
# (254, 151, 5, 't3', <gurobi.Var TEL-t3_ID-254_ST-151 (value 1.0)>)
# (256, 194, 3, 't3', <gurobi.Var TEL-t3_ID-256_ST-194 (value 1.0)>)
# (257, 128, 1, 't3', <gurobi.Var TEL-t3_ID-257_ST-128 (value 1.0)>)
# (262, 202, 5, 't3', <gurobi.Var TEL-t3_ID-262_ST-202 (value 1.0)>)
# (265, 207, 1, 't2', <gurobi.Var TEL-t2_ID-265_ST-207 (value 1.0)>)
# (266, 190, 1, 't1', <gurobi.Var TEL-t1_ID-266_ST-190 (value 1.0)>)
# (267, 32, 1, 't1', <gurobi.Var TEL-t1_ID-267_ST-32 (value 1.0)>)
# (270, 186, 4, 't3', <gurobi.Var TEL-t3_ID-270_ST-186 (value 1.0)>)
# (272, 184, 3, 't3', <gurobi.Var TEL-t3_ID-272_ST-184 (value 1.0)>)
# (274, 129, 4, 't1', <gurobi.Var TEL-t1_ID-274_ST-129 (value 1.0)>)
# (280, 17, 2, 't3', <gurobi.Var TEL-t3_ID-280_ST-17 (value 1.0)>)
# (281, 185, 4, 't3', <gurobi.Var TEL-t3_ID-281_ST-185 (value 1.0)>)
# (282, 117, 5, 't3', <gurobi.Var TEL-t3_ID-282_ST-117 (value 1.0)>)
# (283, 219, 2, 't1', <gurobi.Var TEL-t1_ID-283_ST-219 (value 1.0)>)
# (285, 89, 2, 't3', <gurobi.Var TEL-t3_ID-285_ST-89 (value 1.0)>)
# (286, 218, 4, 't1', <gurobi.Var TEL-t1_ID-286_ST-218 (value 1.0)>)
# (287, 61, 2, 't1', <gurobi.Var TEL-t1_ID-287_ST-61 (value 1.0)>)
# (288, 196, 5, 't1', <gurobi.Var TEL-t1_ID-288_ST-196 (value 1.0)>)
# (289, 68, 5, 't2', <gurobi.Var TEL-t2_ID-289_ST-68 (value 1.0)>)
# (292, 123, 2, 't3', <gurobi.Var TEL-t3_ID-292_ST-123 (value 1.0)>)
# (294, 40, 4, 't3', <gurobi.Var TEL-t3_ID-294_ST-40 (value 1.0)>)
# (298, 205, 4, 't1', <gurobi.Var TEL-t1_ID-298_ST-205 (value 1.0)>)
# (299, 36, 5, 't3', <gurobi.Var TEL-t3_ID-299_ST-36 (value 1.0)>)
# (302, 49, 2, 't3', <gurobi.Var TEL-t3_ID-302_ST-49 (value 1.0)>)
# (303, 199, 5, 't1', <gurobi.Var TEL-t1_ID-303_ST-199 (value 1.0)>)
# (307, 229, 4, 't1', <gurobi.Var TEL-t1_ID-307_ST-229 (value 1.0)>)
# (309, 203, 3, 't2', <gurobi.Var TEL-t2_ID-309_ST-203 (value 1.0)>)
# (311, 59, 1, 't1', <gurobi.Var TEL-t1_ID-311_ST-59 (value 1.0)>)
# (312, 33, 5, 't1', <gurobi.Var TEL-t1_ID-312_ST-33 (value 1.0)>)
# (313, 98, 2, 't1', <gurobi.Var TEL-t1_ID-313_ST-98 (value 1.0)>)
# (314, 197, 3, 't3', <gurobi.Var TEL-t3_ID-314_ST-197 (value 1.0)>)
# (315, 47, 3, 't3', <gurobi.Var TEL-t3_ID-315_ST-47 (value 1.0)>)
# (319, 208, 5, 't1', <gurobi.Var TEL-t1_ID-319_ST-208 (value 1.0)>)
# (321, 234, 4, 't2', <gurobi.Var TEL-t2_ID-321_ST-234 (value 1.0)>)
# (322, 42, 2, 't1', <gurobi.Var TEL-t1_ID-322_ST-42 (value 1.0)>)
# (323, 95, 1, 't1', <gurobi.Var TEL-t1_ID-323_ST-95 (value 1.0)>)
# (328, 247, 4, 't3', <gurobi.Var TEL-t3_ID-328_ST-247 (value 1.0)>)
# (329, 153, 5, 't3', <gurobi.Var TEL-t3_ID-329_ST-153 (value 1.0)>)
# (330, 123, 5, 't2', <gurobi.Var TEL-t2_ID-330_ST-123 (value 1.0)>)
# (335, 83, 2, 't3', <gurobi.Var TEL-t3_ID-335_ST-83 (value 1.0)>)
# (336, 187, 3, 't3', <gurobi.Var TEL-t3_ID-336_ST-187 (value 1.0)>)
# (337, 119, 3, 't1', <gurobi.Var TEL-t1_ID-337_ST-119 (value 1.0)>)
# (338, 177, 5, 't2', <gurobi.Var TEL-t2_ID-338_ST-177 (value 1.0)>)
# (340, 235, 3, 't2', <gurobi.Var TEL-t2_ID-340_ST-235 (value 1.0)>)
# (343, 34, 4, 't1', <gurobi.Var TEL-t1_ID-343_ST-34 (value 1.0)>)
# (344, 76, 2, 't2', <gurobi.Var TEL-t2_ID-344_ST-76 (value 1.0)>)
# (345, 72, 2, 't1', <gurobi.Var TEL-t1_ID-345_ST-72 (value 1.0)>)
# (346, 66, 5, 't2', <gurobi.Var TEL-t2_ID-346_ST-66 (value 1.0)>)
# (348, 43, 3, 't3', <gurobi.Var TEL-t3_ID-348_ST-43 (value 1.0)>)
# (349, 197, 5, 't2', <gurobi.Var TEL-t2_ID-349_ST-197 (value 1.0)>)
# (350, 213, 2, 't1', <gurobi.Var TEL-t1_ID-350_ST-213 (value 1.0)>)
# (351, 116, 4, 't1', <gurobi.Var TEL-t1_ID-351_ST-116 (value 1.0)>)
# (353, 223, 4, 't1', <gurobi.Var TEL-t1_ID-353_ST-223 (value 1.0)>)
# (354, 196, 1, 't3', <gurobi.Var TEL-t3_ID-354_ST-196 (value 1.0)>)
# (358, 126, 3, 't3', <gurobi.Var TEL-t3_ID-358_ST-126 (value 1.0)>)
# (359, 82, 2, 't3', <gurobi.Var TEL-t3_ID-359_ST-82 (value 1.0)>)
# (362, 211, 4, 't2', <gurobi.Var TEL-t2_ID-362_ST-211 (value 1.0)>)
# (364, 38, 5, 't3', <gurobi.Var TEL-t3_ID-364_ST-38 (value 1.0)>)
# (368, 97, 1, 't1', <gurobi.Var TEL-t1_ID-368_ST-97 (value 1.0)>)
# (371, 76, 1, 't1', <gurobi.Var TEL-t1_ID-371_ST-76 (value 1.0)>)
# (374, 124, 1, 't3', <gurobi.Var TEL-t3_ID-374_ST-124 (value 1.0)>)
# (375, 230, 5, 't1', <gurobi.Var TEL-t1_ID-375_ST-230 (value 1.0)>)
# (376, 217, 3, 't1', <gurobi.Var TEL-t1_ID-376_ST-217 (value 1.0)>)
# (378, 70, 4, 't1', <gurobi.Var TEL-t1_ID-378_ST-70 (value 1.0)>)
# (379, 223, 5, 't3', <gurobi.Var TEL-t3_ID-379_ST-223 (value 1.0)>)
# (380, 180, 5, 't2', <gurobi.Var TEL-t2_ID-380_ST-180 (value 1.0)>)
# (383, 119, 2, 't3', <gurobi.Var TEL-t3_ID-383_ST-119 (value 1.0)>)
# (384, 139, 2, 't3', <gurobi.Var TEL-t3_ID-384_ST-139 (value 1.0)>)
# (385, 106, 3, 't2', <gurobi.Var TEL-t2_ID-385_ST-106 (value 1.0)>)
# (386, 125, 2, 't3', <gurobi.Var TEL-t3_ID-386_ST-125 (value 1.0)>)
# (387, 248, 4, 't3', <gurobi.Var TEL-t3_ID-387_ST-248 (value 1.0)>)
# (392, 251, 1, 't3', <gurobi.Var TEL-t3_ID-392_ST-251 (value 1.0)>)
# (394, 210, 1, 't2', <gurobi.Var TEL-t2_ID-394_ST-210 (value 1.0)>)
# (395, 134, 3, 't3', <gurobi.Var TEL-t3_ID-395_ST-134 (value 1.0)>)
# (396, 187, 4, 't2', <gurobi.Var TEL-t2_ID-396_ST-187 (value 1.0)>)
# (400, 120, 2, 't3', <gurobi.Var TEL-t3_ID-400_ST-120 (value 1.0)>)
# (401, 198, 5, 't2', <gurobi.Var TEL-t2_ID-401_ST-198 (value 1.0)>)
# (402, 182, 5, 't2', <gurobi.Var TEL-t2_ID-402_ST-182 (value 1.0)>)
# (403, 35, 4, 't3', <gurobi.Var TEL-t3_ID-403_ST-35 (value 1.0)>)
# (404, 232, 5, 't2', <gurobi.Var TEL-t2_ID-404_ST-232 (value 1.0)>)
# (405, 164, 3, 't1', <gurobi.Var TEL-t1_ID-405_ST-164 (value 1.0)>)
# (406, 71, 2, 't2', <gurobi.Var TEL-t2_ID-406_ST-71 (value 1.0)>)
# (408, 236, 4, 't2', <gurobi.Var TEL-t2_ID-408_ST-236 (value 1.0)>)
# (409, 88, 1, 't3', <gurobi.Var TEL-t3_ID-409_ST-88 (value 1.0)>)
# (410, 186, 5, 't2', <gurobi.Var TEL-t2_ID-410_ST-186 (value 1.0)>)
# (411, 132, 5, 't1', <gurobi.Var TEL-t1_ID-411_ST-132 (value 1.0)>)
# (412, 246, 1, 't2', <gurobi.Var TEL-t2_ID-412_ST-246 (value 1.0)>)
# (417, 83, 5, 't1', <gurobi.Var TEL-t1_ID-417_ST-83 (value 1.0)>)
# (418, 243, 1, 't2', <gurobi.Var TEL-t2_ID-418_ST-243 (value 1.0)>)
# (419, 205, 2, 't2', <gurobi.Var TEL-t2_ID-419_ST-205 (value 1.0)>)
# (422, 195, 4, 't1', <gurobi.Var TEL-t1_ID-422_ST-195 (value 1.0)>)
# (424, 148, 4, 't2', <gurobi.Var TEL-t2_ID-424_ST-148 (value 1.0)>)
# (427, 201, 4, 't3', <gurobi.Var TEL-t3_ID-427_ST-201 (value 1.0)>)
# (432, 200, 4, 't2', <gurobi.Var TEL-t2_ID-432_ST-200 (value 1.0)>)
# (433, 216, 1, 't3', <gurobi.Var TEL-t3_ID-433_ST-216 (value 1.0)>)
# (434, 98, 4, 't2', <gurobi.Var TEL-t2_ID-434_ST-98 (value 1.0)>)
# (439, 198, 4, 't3', <gurobi.Var TEL-t3_ID-439_ST-198 (value 1.0)>)
# (441, 195, 4, 't3', <gurobi.Var TEL-t3_ID-441_ST-195 (value 1.0)>)
# (444, 18, 4, 't2', <gurobi.Var TEL-t2_ID-444_ST-18 (value 1.0)>)
# (445, 181, 5, 't2', <gurobi.Var TEL-t2_ID-445_ST-181 (value 1.0)>)
# (446, 143, 3, 't2', <gurobi.Var TEL-t2_ID-446_ST-143 (value 1.0)>)
# (447, 249, 3, 't2', <gurobi.Var TEL-t2_ID-447_ST-249 (value 1.0)>)
# (448, 100, 3, 't1', <gurobi.Var TEL-t1_ID-448_ST-100 (value 1.0)>)
# (449, 99, 2, 't2', <gurobi.Var TEL-t2_ID-449_ST-99 (value 1.0)>)
# (451, 44, 5, 't3', <gurobi.Var TEL-t3_ID-451_ST-44 (value 1.0)>)
# (452, 135, 3, 't3', <gurobi.Var TEL-t3_ID-452_ST-135 (value 1.0)>)
# (454, 202, 4, 't1', <gurobi.Var TEL-t1_ID-454_ST-202 (value 1.0)>)
# (455, 191, 5, 't2', <gurobi.Var TEL-t2_ID-455_ST-191 (value 1.0)>)
# (456, 195, 4, 't2', <gurobi.Var TEL-t2_ID-456_ST-195 (value 1.0)>)
# (458, 251, 1, 't2', <gurobi.Var TEL-t2_ID-458_ST-251 (value 1.0)>)
# (460, 203, 5, 't1', <gurobi.Var TEL-t1_ID-460_ST-203 (value 1.0)>)
# (461, 213, 5, 't2', <gurobi.Var TEL-t2_ID-461_ST-213 (value 1.0)>)
# (462, 161, 2, 't3', <gurobi.Var TEL-t3_ID-462_ST-161 (value 1.0)>)
# (463, 121, 3, 't1', <gurobi.Var TEL-t1_ID-463_ST-121 (value 1.0)>)
# (465, 27, 1, 't1', <gurobi.Var TEL-t1_ID-465_ST-27 (value 1.0)>)
# (466, 63, 5, 't2', <gurobi.Var TEL-t2_ID-466_ST-63 (value 1.0)>)
# (467, 154, 3, 't3', <gurobi.Var TEL-t3_ID-467_ST-154 (value 1.0)>)
# (471, 145, 4, 't1', <gurobi.Var TEL-t1_ID-471_ST-145 (value 1.0)>)
# (472, 174, 4, 't1', <gurobi.Var TEL-t1_ID-472_ST-174 (value 1.0)>)
# (477, 73, 4, 't1', <gurobi.Var TEL-t1_ID-477_ST-73 (value 1.0)>)
# (478, 185, 5, 't2', <gurobi.Var TEL-t2_ID-478_ST-185 (value 1.0)>)
# (481, 67, 4, 't3', <gurobi.Var TEL-t3_ID-481_ST-67 (value 1.0)>)
# (484, 194, 5, 't2', <gurobi.Var TEL-t2_ID-484_ST-194 (value 1.0)>)
# (485, 43, 1, 't1', <gurobi.Var TEL-t1_ID-485_ST-43 (value 1.0)>)
# (486, 157, 1, 't3', <gurobi.Var TEL-t3_ID-486_ST-157 (value 1.0)>)
# (490, 0, 1, 't2', <gurobi.Var TEL-t2_ID-490_ST-0 (value 1.0)>)
# (492, 233, 4, 't2', <gurobi.Var TEL-t2_ID-492_ST-233 (value 1.0)>)
# (493, 164, 5, 't3', <gurobi.Var TEL-t3_ID-493_ST-164 (value 1.0)>)
# (494, 183, 5, 't2', <gurobi.Var TEL-t2_ID-494_ST-183 (value 1.0)>)
# (495, 80, 1, 't3', <gurobi.Var TEL-t3_ID-495_ST-80 (value 1.0)>)
# (497, 67, 3, 't2', <gurobi.Var TEL-t2_ID-497_ST-67 (value 1.0)>)
# (498, 152, 3, 't3', <gurobi.Var TEL-t3_ID-498_ST-152 (value 1.0)>)
# (499, 178, 5, 't3', <gurobi.Var TEL-t3_ID-499_ST-178 (value 1.0)>)

# %%
requests
# Out:
# {0: {'window_start': 94, 'window_end': 197, 'length': 47, 'priority': 3},
#  1: {'window_start': 207, 'window_end': 233, 'length': 26, 'priority': 4},
#  2: {'window_start': 51, 'window_end': 110, 'length': 41, 'priority': 3},
#  3: {'window_start': 3, 'window_end': 186, 'length': 29, 'priority': 1},
#  4: {'window_start': 234, 'window_end': 271, 'length': 37, 'priority': 5},
#  5: {'window_start': 128, 'window_end': 253, 'length': 35, 'priority': 5},
#  6: {'window_start': 98, 'window_end': 251, 'length': 20, 'priority': 1},
#  7: {'window_start': 37, 'window_end': 248, 'length': 29, 'priority': 4},
#  8: {'window_start': 84, 'window_end': 103, 'length': 17, 'priority': 2},
#  9: {'window_start': 287, 'window_end': 295, 'length': 8, 'priority': 1},
#  10: {'window_start': 91, 'window_end': 102, 'length': 11, 'priority': 2},
#  11: {'window_start': 232, 'window_end': 289, 'length': 8, 'priority': 3},
#  12: {'window_start': 98, 'window_end': 188, 'length': 34, 'priority': 1},
#  13: {'window_start': 0, 'window_end': 166, 'length': 29, 'priority': 3},
#  14: {'window_start': 22, 'window_end': 250, 'length': 41, 'priority': 3},
#  15: {'window_start': 91, 'window_end': 150, 'length': 41, 'priority': 4},
#  16: {'window_start': 289, 'window_end': 299, 'length': 10, 'priority': 3},
#  17: {'window_start': 243, 'window_end': 265, 'length': 22, 'priority': 2},
#  18: {'window_start': 32, 'window_end': 103, 'length': 36, 'priority': 1},
#  19: {'window_start': 186, 'window_end': 274, 'length': 5, 'priority': 3},
#  20: {'window_start': 3, 'window_end': 91, 'length': 3, 'priority': 4},
#  21: {'window_start': 80, 'window_end': 167, 'length': 7, 'priority': 2},
#  22: {'window_start': 186, 'window_end': 297, 'length': 16, 'priority': 4},
#  23: {'window_start': 260, 'window_end': 275, 'length': 4, 'priority': 1},
#  24: {'window_start': 117, 'window_end': 279, 'length': 44, 'priority': 3},
#  25: {'window_start': 72, 'window_end': 292, 'length': 19, 'priority': 5},
#  26: {'window_start': 127, 'window_end': 178, 'length': 23, 'priority': 5},
#  27: {'window_start': 76, 'window_end': 192, 'length': 30, 'priority': 4},
#  28: {'window_start': 29, 'window_end': 207, 'length': 30, 'priority': 4},
#  29: {'window_start': 11, 'window_end': 41, 'length': 18, 'priority': 4},
#  30: {'window_start': 156, 'window_end': 186, 'length': 8, 'priority': 1},
#  31: {'window_start': 48, 'window_end': 92, 'length': 27, 'priority': 1},
#  32: {'window_start': 202, 'window_end': 216, 'length': 14, 'priority': 2},
#  33: {'window_start': 39, 'window_end': 222, 'length': 3, 'priority': 3},
#  34: {'window_start': 94, 'window_end': 188, 'length': 28, 'priority': 3},
#  35: {'window_start': 10, 'window_end': 211, 'length': 15, 'priority': 5},
#  36: {'window_start': 182, 'window_end': 260, 'length': 15, 'priority': 4},
#  37: {'window_start': 181, 'window_end': 189, 'length': 8, 'priority': 5},
#  38: {'window_start': 81, 'window_end': 116, 'length': 24, 'priority': 1},
#  39: {'window_start': 80, 'window_end': 125, 'length': 32, 'priority': 3},
#  40: {'window_start': 70, 'window_end': 99, 'length': 29, 'priority': 4},
#  41: {'window_start': 226, 'window_end': 270, 'length': 11, 'priority': 4},
#  42: {'window_start': 130, 'window_end': 195, 'length': 49, 'priority': 5},
#  43: {'window_start': 47, 'window_end': 200, 'length': 14, 'priority': 4},
#  44: {'window_start': 54, 'window_end': 107, 'length': 49, 'priority': 5},
#  45: {'window_start': 182, 'window_end': 185, 'length': 3, 'priority': 3},
#  46: {'window_start': 193, 'window_end': 287, 'length': 50, 'priority': 4},
#  47: {'window_start': 78, 'window_end': 176, 'length': 34, 'priority': 1},
#  48: {'window_start': 146, 'window_end': 164, 'length': 18, 'priority': 3},
#  49: {'window_start': 98, 'window_end': 99, 'length': 1, 'priority': 4},
#  50: {'window_start': 109, 'window_end': 110, 'length': 1, 'priority': 2},
#  51: {'window_start': 134, 'window_end': 191, 'length': 29, 'priority': 2},
#  52: {'window_start': 56, 'window_end': 60, 'length': 4, 'priority': 5},
#  53: {'window_start': 9, 'window_end': 296, 'length': 27, 'priority': 1},
#  54: {'window_start': 279, 'window_end': 299, 'length': 20, 'priority': 3},
#  55: {'window_start': 64, 'window_end': 182, 'length': 48, 'priority': 5},
#  56: {'window_start': 67, 'window_end': 131, 'length': 12, 'priority': 4},
#  57: {'window_start': 133, 'window_end': 197, 'length': 34, 'priority': 2},
#  58: {'window_start': 82, 'window_end': 245, 'length': 6, 'priority': 2},
#  59: {'window_start': 6, 'window_end': 181, 'length': 37, 'priority': 4},
#  60: {'window_start': 30, 'window_end': 285, 'length': 27, 'priority': 4},
#  61: {'window_start': 59, 'window_end': 200, 'length': 21, 'priority': 4},
#  62: {'window_start': 154, 'window_end': 181, 'length': 27, 'priority': 5},
#  63: {'window_start': 39, 'window_end': 205, 'length': 30, 'priority': 2},
#  64: {'window_start': 36, 'window_end': 129, 'length': 29, 'priority': 1},
#  65: {'window_start': 135, 'window_end': 278, 'length': 5, 'priority': 2},
#  66: {'window_start': 178, 'window_end': 276, 'length': 18, 'priority': 2},
#  67: {'window_start': 165, 'window_end': 296, 'length': 27, 'priority': 1},
#  68: {'window_start': 38, 'window_end': 293, 'length': 1, 'priority': 2},
#  69: {'window_start': 100, 'window_end': 115, 'length': 15, 'priority': 1},
#  70: {'window_start': 102, 'window_end': 181, 'length': 11, 'priority': 5},
#  71: {'window_start': 44, 'window_end': 86, 'length': 26, 'priority': 5},
#  72: {'window_start': 11, 'window_end': 233, 'length': 7, 'priority': 3},
#  73: {'window_start': 106, 'window_end': 195, 'length': 27, 'priority': 2},
#  74: {'window_start': 23, 'window_end': 55, 'length': 6, 'priority': 1},
#  75: {'window_start': 155, 'window_end': 287, 'length': 44, 'priority': 2},
#  76: {'window_start': 93, 'window_end': 227, 'length': 12, 'priority': 1},
#  77: {'window_start': 37, 'window_end': 179, 'length': 32, 'priority': 5},
#  78: {'window_start': 72, 'window_end': 78, 'length': 6, 'priority': 2},
#  79: {'window_start': 142, 'window_end': 248, 'length': 26, 'priority': 1},
#  80: {'window_start': 118, 'window_end': 153, 'length': 35, 'priority': 3},
#  81: {'window_start': 35, 'window_end': 88, 'length': 11, 'priority': 5},
#  82: {'window_start': 13, 'window_end': 229, 'length': 8, 'priority': 2},
#  83: {'window_start': 55, 'window_end': 88, 'length': 9, 'priority': 5},
#  84: {'window_start': 108, 'window_end': 161, 'length': 36, 'priority': 4},
#  85: {'window_start': 12, 'window_end': 150, 'length': 6, 'priority': 4},
#  86: {'window_start': 127, 'window_end': 257, 'length': 30, 'priority': 2},
#  87: {'window_start': 61, 'window_end': 207, 'length': 37, 'priority': 5},
#  88: {'window_start': 82, 'window_end': 115, 'length': 33, 'priority': 5},
#  89: {'window_start': 50, 'window_end': 136, 'length': 9, 'priority': 4},
#  90: {'window_start': 13, 'window_end': 209, 'length': 39, 'priority': 4},
#  91: {'window_start': 58, 'window_end': 120, 'length': 35, 'priority': 4},
#  92: {'window_start': 45, 'window_end': 84, 'length': 5, 'priority': 4},
#  93: {'window_start': 15, 'window_end': 89, 'length': 16, 'priority': 3},
#  94: {'window_start': 170, 'window_end': 240, 'length': 45, 'priority': 4},
#  95: {'window_start': 39, 'window_end': 149, 'length': 7, 'priority': 3},
#  96: {'window_start': 31, 'window_end': 293, 'length': 2, 'priority': 3},
#  97: {'window_start': 18, 'window_end': 161, 'length': 5, 'priority': 2},
#  98: {'window_start': 61, 'window_end': 132, 'length': 2, 'priority': 3},
#  99: {'window_start': 3, 'window_end': 240, 'length': 27, 'priority': 4},
#  100: {'window_start': 25, 'window_end': 128, 'length': 22, 'priority': 2},
#  101: {'window_start': 180, 'window_end': 280, 'length': 14, 'priority': 1},
#  102: {'window_start': 164, 'window_end': 296, 'length': 20, 'priority': 5},
#  103: {'window_start': 79, 'window_end': 194, 'length': 25, 'priority': 3},
#  104: {'window_start': 42, 'window_end': 299, 'length': 14, 'priority': 4},
#  105: {'window_start': 46, 'window_end': 260, 'length': 25, 'priority': 3},
#  106: {'window_start': 36, 'window_end': 269, 'length': 36, 'priority': 3},
#  107: {'window_start': 99, 'window_end': 126, 'length': 15, 'priority': 5},
#  108: {'window_start': 201, 'window_end': 297, 'length': 30, 'priority': 3},
#  109: {'window_start': 73, 'window_end': 78, 'length': 5, 'priority': 5},
#  110: {'window_start': 1, 'window_end': 123, 'length': 12, 'priority': 5},
#  111: {'window_start': 190, 'window_end': 232, 'length': 42, 'priority': 4},
#  112: {'window_start': 203, 'window_end': 224, 'length': 21, 'priority': 5},
#  113: {'window_start': 154, 'window_end': 207, 'length': 35, 'priority': 4},
#  114: {'window_start': 40, 'window_end': 155, 'length': 46, 'priority': 5},
#  115: {'window_start': 54, 'window_end': 161, 'length': 6, 'priority': 4},
#  116: {'window_start': 133, 'window_end': 216, 'length': 46, 'priority': 4},
#  117: {'window_start': 49, 'window_end': 152, 'length': 15, 'priority': 4},
#  118: {'window_start': 247, 'window_end': 291, 'length': 11, 'priority': 1},
#  119: {'window_start': 194, 'window_end': 299, 'length': 46, 'priority': 4},
#  120: {'window_start': 108, 'window_end': 224, 'length': 20, 'priority': 1},
#  121: {'window_start': 147, 'window_end': 299, 'length': 44, 'priority': 3},
#  122: {'window_start': 37, 'window_end': 70, 'length': 33, 'priority': 2},
#  123: {'window_start': 21, 'window_end': 21, 'length': 0, 'priority': 4},
#  124: {'window_start': 198, 'window_end': 266, 'length': 40, 'priority': 4},
#  125: {'window_start': 7, 'window_end': 220, 'length': 10, 'priority': 1},
#  126: {'window_start': 192, 'window_end': 210, 'length': 18, 'priority': 1},
#  127: {'window_start': 90, 'window_end': 125, 'length': 35, 'priority': 2},
#  128: {'window_start': 57, 'window_end': 191, 'length': 44, 'priority': 5},
#  129: {'window_start': 177, 'window_end': 180, 'length': 3, 'priority': 1},
#  130: {'window_start': 158, 'window_end': 185, 'length': 27, 'priority': 1},
#  131: {'window_start': 142, 'window_end': 251, 'length': 22, 'priority': 1},
#  132: {'window_start': 104, 'window_end': 193, 'length': 46, 'priority': 1},
#  133: {'window_start': 3, 'window_end': 129, 'length': 6, 'priority': 2},
#  134: {'window_start': 164, 'window_end': 297, 'length': 31, 'priority': 1},
#  135: {'window_start': 203, 'window_end': 244, 'length': 1, 'priority': 4},
#  136: {'window_start': 9, 'window_end': 154, 'length': 29, 'priority': 5},
#  137: {'window_start': 69, 'window_end': 206, 'length': 16, 'priority': 2},
#  138: {'window_start': 222, 'window_end': 256, 'length': 7, 'priority': 1},
#  139: {'window_start': 37, 'window_end': 59, 'length': 16, 'priority': 1},
#  140: {'window_start': 126, 'window_end': 165, 'length': 21, 'priority': 4},
#  141: {'window_start': 23, 'window_end': 282, 'length': 27, 'priority': 2},
#  142: {'window_start': 38, 'window_end': 174, 'length': 8, 'priority': 4},
#  143: {'window_start': 124, 'window_end': 195, 'length': 12, 'priority': 3},
#  144: {'window_start': 87, 'window_end': 183, 'length': 24, 'priority': 5},
#  145: {'window_start': 51, 'window_end': 170, 'length': 12, 'priority': 4},
#  146: {'window_start': 43, 'window_end': 175, 'length': 12, 'priority': 3},
#  147: {'window_start': 47, 'window_end': 115, 'length': 9, 'priority': 4},
#  148: {'window_start': 155, 'window_end': 283, 'length': 40, 'priority': 4},
#  149: {'window_start': 148, 'window_end': 266, 'length': 33, 'priority': 1},
#  150: {'window_start': 33, 'window_end': 203, 'length': 13, 'priority': 1},
#  151: {'window_start': 37, 'window_end': 288, 'length': 16, 'priority': 3},
#  152: {'window_start': 103, 'window_end': 161, 'length': 12, 'priority': 2},
#  153: {'window_start': 268, 'window_end': 293, 'length': 8, 'priority': 2},
#  154: {'window_start': 100, 'window_end': 175, 'length': 41, 'priority': 3},
#  155: {'window_start': 38, 'window_end': 121, 'length': 43, 'priority': 2},
#  156: {'window_start': 5, 'window_end': 204, 'length': 16, 'priority': 3},
#  157: {'window_start': 24, 'window_end': 158, 'length': 24, 'priority': 4},
#  158: {'window_start': 170, 'window_end': 189, 'length': 19, 'priority': 3},
#  159: {'window_start': 172, 'window_end': 294, 'length': 29, 'priority': 5},
#  160: {'window_start': 50, 'window_end': 173, 'length': 46, 'priority': 2},
#  161: {'window_start': 133, 'window_end': 296, 'length': 31, 'priority': 2},
#  162: {'window_start': 228, 'window_end': 290, 'length': 20, 'priority': 2},
#  163: {'window_start': 54, 'window_end': 187, 'length': 31, 'priority': 1},
#  164: {'window_start': 254, 'window_end': 261, 'length': 7, 'priority': 2},
#  165: {'window_start': 76, 'window_end': 173, 'length': 4, 'priority': 3},
#  166: {'window_start': 31, 'window_end': 140, 'length': 1, 'priority': 2},
#  167: {'window_start': 155, 'window_end': 189, 'length': 17, 'priority': 2},
#  168: {'window_start': 65, 'window_end': 227, 'length': 10, 'priority': 3},
#  169: {'window_start': 186, 'window_end': 267, 'length': 39, 'priority': 5},
#  170: {'window_start': 110, 'window_end': 264, 'length': 45, 'priority': 3},
#  171: {'window_start': 164, 'window_end': 217, 'length': 46, 'priority': 1},
#  172: {'window_start': 119, 'window_end': 213, 'length': 37, 'priority': 1},
#  173: {'window_start': 130, 'window_end': 291, 'length': 50, 'priority': 1},
#  174: {'window_start': 70, 'window_end': 263, 'length': 2, 'priority': 4},
#  175: {'window_start': 132, 'window_end': 224, 'length': 21, 'priority': 3},
#  176: {'window_start': 106, 'window_end': 146, 'length': 26, 'priority': 1},
#  177: {'window_start': 8, 'window_end': 60, 'length': 43, 'priority': 4},
#  178: {'window_start': 45, 'window_end': 270, 'length': 10, 'priority': 5},
#  179: {'window_start': 82, 'window_end': 259, 'length': 29, 'priority': 2},
#  180: {'window_start': 139, 'window_end': 168, 'length': 29, 'priority': 4},
#  181: {'window_start': 29, 'window_end': 201, 'length': 16, 'priority': 1},
#  182: {'window_start': 192, 'window_end': 258, 'length': 36, 'priority': 3},
#  183: {'window_start': 130, 'window_end': 144, 'length': 11, 'priority': 3},
#  184: {'window_start': 9, 'window_end': 113, 'length': 48, 'priority': 1},
#  185: {'window_start': 64, 'window_end': 88, 'length': 14, 'priority': 5},
#  186: {'window_start': 38, 'window_end': 213, 'length': 1, 'priority': 4},
#  187: {'window_start': 209, 'window_end': 266, 'length': 50, 'priority': 4},
#  188: {'window_start': 47, 'window_end': 122, 'length': 21, 'priority': 5},
#  189: {'window_start': 132, 'window_end': 263, 'length': 23, 'priority': 1},
#  190: {'window_start': 108, 'window_end': 299, 'length': 16, 'priority': 5},
#  191: {'window_start': 228, 'window_end': 241, 'length': 13, 'priority': 5},
#  192: {'window_start': 11, 'window_end': 254, 'length': 30, 'priority': 3},
#  193: {'window_start': 85, 'window_end': 172, 'length': 49, 'priority': 1},
#  194: {'window_start': 12, 'window_end': 179, 'length': 17, 'priority': 4},
#  195: {'window_start': 225, 'window_end': 272, 'length': 21, 'priority': 3},
#  196: {'window_start': 15, 'window_end': 50, 'length': 35, 'priority': 5},
#  197: {'window_start': 73, 'window_end': 130, 'length': 49, 'priority': 5},
#  198: {'window_start': 48, 'window_end': 149, 'length': 29, 'priority': 3},
#  199: {'window_start': 229, 'window_end': 250, 'length': 6, 'priority': 5},
#  200: {'window_start': 143, 'window_end': 151, 'length': 4, 'priority': 3},
#  201: {'window_start': 141, 'window_end': 219, 'length': 15, 'priority': 3},
#  202: {'window_start': 79, 'window_end': 122, 'length': 31, 'priority': 2},
#  203: {'window_start': 190, 'window_end': 285, 'length': 5, 'priority': 1},
#  204: {'window_start': 11, 'window_end': 284, 'length': 32, 'priority': 5},
#  205: {'window_start': 144, 'window_end': 217, 'length': 43, 'priority': 5},
#  206: {'window_start': 192, 'window_end': 203, 'length': 11, 'priority': 3},
#  207: {'window_start': 26, 'window_end': 232, 'length': 33, 'priority': 4},
#  208: {'window_start': 50, 'window_end': 257, 'length': 12, 'priority': 5},
#  209: {'window_start': 77, 'window_end': 127, 'length': 21, 'priority': 3},
#  210: {'window_start': 32, 'window_end': 98, 'length': 19, 'priority': 5},
#  211: {'window_start': 204, 'window_end': 266, 'length': 17, 'priority': 3},
#  212: {'window_start': 110, 'window_end': 165, 'length': 1, 'priority': 5},
#  213: {'window_start': 9, 'window_end': 230, 'length': 6, 'priority': 3},
#  214: {'window_start': 157, 'window_end': 221, 'length': 7, 'priority': 2},
#  215: {'window_start': 63, 'window_end': 296, 'length': 23, 'priority': 1},
#  216: {'window_start': 66, 'window_end': 89, 'length': 23, 'priority': 5},
#  217: {'window_start': 97, 'window_end': 284, 'length': 13, 'priority': 4},
#  218: {'window_start': 155, 'window_end': 249, 'length': 14, 'priority': 5},
#  219: {'window_start': 156, 'window_end': 162, 'length': 6, 'priority': 3},
#  220: {'window_start': 274, 'window_end': 294, 'length': 20, 'priority': 2},
#  221: {'window_start': 185, 'window_end': 191, 'length': 6, 'priority': 3},
#  222: {'window_start': 97, 'window_end': 141, 'length': 27, 'priority': 5},
#  223: {'window_start': 184, 'window_end': 237, 'length': 45, 'priority': 4},
#  224: {'window_start': 41, 'window_end': 50, 'length': 1, 'priority': 4},
#  225: {'window_start': 225, 'window_end': 231, 'length': 6, 'priority': 5},
#  226: {'window_start': 227, 'window_end': 268, 'length': 23, 'priority': 3},
#  227: {'window_start': 183, 'window_end': 238, 'length': 3, 'priority': 3},
#  228: {'window_start': 61, 'window_end': 81, 'length': 4, 'priority': 1},
#  229: {'window_start': 24, 'window_end': 145, 'length': 24, 'priority': 4},
#  230: {'window_start': 236, 'window_end': 271, 'length': 35, 'priority': 3},
#  231: {'window_start': 0, 'window_end': 2, 'length': 2, 'priority': 3},
#  232: {'window_start': 232, 'window_end': 297, 'length': 20, 'priority': 5},
#  233: {'window_start': 118, 'window_end': 192, 'length': 39, 'priority': 3},
#  234: {'window_start': 183, 'window_end': 204, 'length': 21, 'priority': 2},
#  235: {'window_start': 121, 'window_end': 253, 'length': 13, 'priority': 5},
#  236: {'window_start': 66, 'window_end': 108, 'length': 42, 'priority': 1},
#  237: {'window_start': 134, 'window_end': 233, 'length': 20, 'priority': 2},
#  238: {'window_start': 241, 'window_end': 260, 'length': 8, 'priority': 4},
#  239: {'window_start': 193, 'window_end': 239, 'length': 19, 'priority': 2},
#  240: {'window_start': 23, 'window_end': 248, 'length': 6, 'priority': 3},
#  241: {'window_start': 38, 'window_end': 122, 'length': 48, 'priority': 4},
#  242: {'window_start': 11, 'window_end': 227, 'length': 9, 'priority': 4},
#  243: {'window_start': 25, 'window_end': 57, 'length': 32, 'priority': 4},
#  244: {'window_start': 219, 'window_end': 241, 'length': 22, 'priority': 1},
#  245: {'window_start': 61, 'window_end': 159, 'length': 1, 'priority': 5},
#  246: {'window_start': 139, 'window_end': 183, 'length': 18, 'priority': 2},
#  247: {'window_start': 48, 'window_end': 286, 'length': 23, 'priority': 5},
#  248: {'window_start': 36, 'window_end': 243, 'length': 17, 'priority': 5},
#  249: {'window_start': 39, 'window_end': 192, 'length': 35, 'priority': 4},
#  250: {'window_start': 1, 'window_end': 45, 'length': 20, 'priority': 3},
#  251: {'window_start': 160, 'window_end': 170, 'length': 10, 'priority': 5},
#  252: {'window_start': 70, 'window_end': 154, 'length': 24, 'priority': 3},
#  253: {'window_start': 127, 'window_end': 270, 'length': 30, 'priority': 1},
#  254: {'window_start': 79, 'window_end': 261, 'length': 23, 'priority': 5},
#  255: {'window_start': 126, 'window_end': 190, 'length': 38, 'priority': 1},
#  256: {'window_start': 183, 'window_end': 290, 'length': 14, 'priority': 3},
#  257: {'window_start': 96, 'window_end': 271, 'length': 10, 'priority': 1},
#  258: {'window_start': 43, 'window_end': 269, 'length': 47, 'priority': 5},
#  259: {'window_start': 200, 'window_end': 260, 'length': 35, 'priority': 5},
#  260: {'window_start': 28, 'window_end': 59, 'length': 31, 'priority': 2},
#  261: {'window_start': 252, 'window_end': 284, 'length': 27, 'priority': 5},
#  262: {'window_start': 179, 'window_end': 186, 'length': 7, 'priority': 5},
#  263: {'window_start': 38, 'window_end': 205, 'length': 48, 'priority': 4},
#  264: {'window_start': 101, 'window_end': 192, 'length': 49, 'priority': 2},
#  265: {'window_start': 197, 'window_end': 242, 'length': 13, 'priority': 1},
#  266: {'window_start': 189, 'window_end': 190, 'length': 1, 'priority': 1},
#  267: {'window_start': 31, 'window_end': 174, 'length': 21, 'priority': 1},
#  268: {'window_start': 106, 'window_end': 268, 'length': 47, 'priority': 4},
#  269: {'window_start': 97, 'window_end': 137, 'length': 38, 'priority': 3},
#  270: {'window_start': 185, 'window_end': 282, 'length': 23, 'priority': 4},
#  271: {'window_start': 223, 'window_end': 262, 'length': 39, 'priority': 5},
#  272: {'window_start': 95, 'window_end': 207, 'length': 25, 'priority': 3},
#  273: {'window_start': 202, 'window_end': 279, 'length': 32, 'priority': 5},
#  274: {'window_start': 9, 'window_end': 151, 'length': 5, 'priority': 4},
#  275: {'window_start': 279, 'window_end': 279, 'length': 0, 'priority': 1},
#  276: {'window_start': 57, 'window_end': 191, 'length': 32, 'priority': 3},
#  277: {'window_start': 109, 'window_end': 139, 'length': 30, 'priority': 1},
#  278: {'window_start': 244, 'window_end': 299, 'length': 31, 'priority': 5},
#  279: {'window_start': 147, 'window_end': 257, 'length': 46, 'priority': 4},
#  280: {'window_start': 11, 'window_end': 294, 'length': 1, 'priority': 2},
#  281: {'window_start': 122, 'window_end': 217, 'length': 24, 'priority': 4},
#  282: {'window_start': 77, 'window_end': 296, 'length': 21, 'priority': 5},
#  283: {'window_start': 147, 'window_end': 191, 'length': 13, 'priority': 2},
#  284: {'window_start': 0, 'window_end': 135, 'length': 33, 'priority': 4},
#  285: {'window_start': 36, 'window_end': 46, 'length': 10, 'priority': 2},
#  286: {'window_start': 166, 'window_end': 199, 'length': 15, 'priority': 4},
#  287: {'window_start': 19, 'window_end': 20, 'length': 1, 'priority': 2},
#  288: {'window_start': 23, 'window_end': 170, 'length': 37, 'priority': 5},
#  289: {'window_start': 38, 'window_end': 55, 'length': 17, 'priority': 5},
#  290: {'window_start': 108, 'window_end': 172, 'length': 31, 'priority': 1},
#  291: {'window_start': 138, 'window_end': 240, 'length': 33, 'priority': 1},
#  292: {'window_start': 20, 'window_end': 102, 'length': 11, 'priority': 2},
#  293: {'window_start': 269, 'window_end': 275, 'length': 6, 'priority': 1},
#  294: {'window_start': 15, 'window_end': 52, 'length': 25, 'priority': 4},
#  295: {'window_start': 13, 'window_end': 140, 'length': 31, 'priority': 2},
#  296: {'window_start': 74, 'window_end': 185, 'length': 43, 'priority': 4},
#  297: {'window_start': 167, 'window_end': 233, 'length': 47, 'priority': 3},
#  298: {'window_start': 188, 'window_end': 263, 'length': 27, 'priority': 4},
#  299: {'window_start': 26, 'window_end': 204, 'length': 30, 'priority': 5},
#  300: {'window_start': 49, 'window_end': 286, 'length': 24, 'priority': 2},
#  301: {'window_start': 11, 'window_end': 137, 'length': 49, 'priority': 2},
#  302: {'window_start': 44, 'window_end': 92, 'length': 17, 'priority': 2},
#  303: {'window_start': 124, 'window_end': 247, 'length': 34, 'priority': 5},
#  304: {'window_start': 63, 'window_end': 137, 'length': 35, 'priority': 2},
#  305: {'window_start': 88, 'window_end': 145, 'length': 33, 'priority': 1},
#  306: {'window_start': 150, 'window_end': 249, 'length': 35, 'priority': 2},
#  307: {'window_start': 201, 'window_end': 260, 'length': 2, 'priority': 4},
#  308: {'window_start': 101, 'window_end': 132, 'length': 30, 'priority': 1},
#  309: {'window_start': 192, 'window_end': 231, 'length': 19, 'priority': 3},
#  310: {'window_start': 251, 'window_end': 270, 'length': 14, 'priority': 3},
#  311: {'window_start': 59, 'window_end': 116, 'length': 6, 'priority': 1},
#  312: {'window_start': 33, 'window_end': 262, 'length': 14, 'priority': 5},
#  313: {'window_start': 50, 'window_end': 221, 'length': 14, 'priority': 2},
#  314: {'window_start': 91, 'window_end': 290, 'length': 11, 'priority': 3},
#  315: {'window_start': 38, 'window_end': 91, 'length': 19, 'priority': 3},
#  316: {'window_start': 76, 'window_end': 231, 'length': 24, 'priority': 1},
#  317: {'window_start': 20, 'window_end': 96, 'length': 47, 'priority': 5},
#  318: {'window_start': 180, 'window_end': 290, 'length': 29, 'priority': 3},
#  319: {'window_start': 155, 'window_end': 277, 'length': 25, 'priority': 5},
#  320: {'window_start': 18, 'window_end': 281, 'length': 44, 'priority': 1},
#  321: {'window_start': 1, 'window_end': 178, 'length': 26, 'priority': 4},
#  322: {'window_start': 42, 'window_end': 89, 'length': 11, 'priority': 2},
#  323: {'window_start': 67, 'window_end': 186, 'length': 18, 'priority': 1},
#  324: {'window_start': 52, 'window_end': 89, 'length': 30, 'priority': 2},
#  325: {'window_start': 52, 'window_end': 198, 'length': 49, 'priority': 1},
#  326: {'window_start': 103, 'window_end': 142, 'length': 39, 'priority': 4},
#  327: {'window_start': 153, 'window_end': 290, 'length': 39, 'priority': 1},
#  328: {'window_start': 125, 'window_end': 138, 'length': 13, 'priority': 4},
#  329: {'window_start': 90, 'window_end': 236, 'length': 21, 'priority': 5},
#  330: {'window_start': 91, 'window_end': 291, 'length': 13, 'priority': 5},
#  331: {'window_start': 94, 'window_end': 205, 'length': 28, 'priority': 1},
#  332: {'window_start': 258, 'window_end': 273, 'length': 15, 'priority': 4},
#  333: {'window_start': 81, 'window_end': 156, 'length': 49, 'priority': 2},
#  334: {'window_start': 117, 'window_end': 241, 'length': 33, 'priority': 2},
#  335: {'window_start': 20, 'window_end': 299, 'length': 12, 'priority': 2},
#  336: {'window_start': 142, 'window_end': 207, 'length': 22, 'priority': 3},
#  337: {'window_start': 119, 'window_end': 149, 'length': 2, 'priority': 3},
#  338: {'window_start': 101, 'window_end': 147, 'length': 45, 'priority': 5},
#  339: {'window_start': 184, 'window_end': 263, 'length': 49, 'priority': 5},
#  340: {'window_start': 192, 'window_end': 216, 'length': 24, 'priority': 3},
#  341: {'window_start': 117, 'window_end': 230, 'length': 26, 'priority': 2},
#  342: {'window_start': 79, 'window_end': 183, 'length': 23, 'priority': 1},
#  343: {'window_start': 34, 'window_end': 152, 'length': 17, 'priority': 4},
#  344: {'window_start': 57, 'window_end': 58, 'length': 1, 'priority': 2},
#  345: {'window_start': 72, 'window_end': 172, 'length': 13, 'priority': 2},
#  346: {'window_start': 14, 'window_end': 143, 'length': 20, 'priority': 5},
#  347: {'window_start': 10, 'window_end': 107, 'length': 25, 'priority': 2},
#  348: {'window_start': 23, 'window_end': 156, 'length': 22, 'priority': 3},
#  349: {'window_start': 89, 'window_end': 224, 'length': 24, 'priority': 5},
#  350: {'window_start': 113, 'window_end': 133, 'length': 20, 'priority': 2},
#  351: {'window_start': 63, 'window_end': 132, 'length': 12, 'priority': 4},
#  352: {'window_start': 181, 'window_end': 289, 'length': 43, 'priority': 3},
#  353: {'window_start': 223, 'window_end': 226, 'length': 3, 'priority': 4},
#  354: {'window_start': 174, 'window_end': 187, 'length': 11, 'priority': 1},
#  355: {'window_start': 193, 'window_end': 241, 'length': 46, 'priority': 3},
#  356: {'window_start': 198, 'window_end': 277, 'length': 44, 'priority': 1},
#  357: {'window_start': 86, 'window_end': 229, 'length': 48, 'priority': 5},
#  358: {'window_start': 26, 'window_end': 38, 'length': 11, 'priority': 3},
#  359: {'window_start': 72, 'window_end': 113, 'length': 19, 'priority': 2},
#  360: {'window_start': 95, 'window_end': 156, 'length': 49, 'priority': 5},
#  361: {'window_start': 145, 'window_end': 184, 'length': 39, 'priority': 3},
#  362: {'window_start': 33, 'window_end': 168, 'length': 11, 'priority': 4},
#  363: {'window_start': 161, 'window_end': 286, 'length': 37, 'priority': 3},
#  364: {'window_start': 17, 'window_end': 240, 'length': 27, 'priority': 5},
#  365: {'window_start': 151, 'window_end': 235, 'length': 47, 'priority': 1},
#  366: {'window_start': 19, 'window_end': 91, 'length': 48, 'priority': 4},
#  367: {'window_start': 83, 'window_end': 249, 'length': 41, 'priority': 4},
#  368: {'window_start': 60, 'window_end': 150, 'length': 15, 'priority': 1},
#  369: {'window_start': 117, 'window_end': 275, 'length': 39, 'priority': 3},
#  370: {'window_start': 40, 'window_end': 200, 'length': 27, 'priority': 3},
#  371: {'window_start': 76, 'window_end': 270, 'length': 13, 'priority': 1},
#  372: {'window_start': 148, 'window_end': 255, 'length': 35, 'priority': 1},
#  373: {'window_start': 250, 'window_end': 280, 'length': 17, 'priority': 1},
#  374: {'window_start': 112, 'window_end': 275, 'length': 10, 'priority': 1},
#  375: {'window_start': 219, 'window_end': 274, 'length': 3, 'priority': 5},
#  376: {'window_start': 132, 'window_end': 148, 'length': 16, 'priority': 3},
#  377: {'window_start': 71, 'window_end': 162, 'length': 44, 'priority': 1},
#  378: {'window_start': 69, 'window_end': 115, 'length': 16, 'priority': 4},
#  379: {'window_start': 223, 'window_end': 260, 'length': 4, 'priority': 5},
#  380: {'window_start': 77, 'window_end': 180, 'length': 38, 'priority': 5},
#  381: {'window_start': 45, 'window_end': 235, 'length': 48, 'priority': 4},
#  382: {'window_start': 48, 'window_end': 232, 'length': 41, 'priority': 2},
#  383: {'window_start': 119, 'window_end': 138, 'length': 19, 'priority': 2},
#  384: {'window_start': 48, 'window_end': 285, 'length': 1, 'priority': 2},
#  385: {'window_start': 36, 'window_end': 182, 'length': 1, 'priority': 3},
#  386: {'window_start': 49, 'window_end': 224, 'length': 12, 'priority': 2},
#  387: {'window_start': 125, 'window_end': 156, 'length': 10, 'priority': 4},
#  388: {'window_start': 145, 'window_end': 289, 'length': 33, 'priority': 2},
#  389: {'window_start': 68, 'window_end': 299, 'length': 36, 'priority': 2},
#  390: {'window_start': 31, 'window_end': 55, 'length': 24, 'priority': 2},
#  391: {'window_start': 33, 'window_end': 279, 'length': 32, 'priority': 2},
#  392: {'window_start': 119, 'window_end': 230, 'length': 9, 'priority': 1},
#  393: {'window_start': 155, 'window_end': 274, 'length': 28, 'priority': 1},
#  394: {'window_start': 12, 'window_end': 290, 'length': 2, 'priority': 1},
#  395: {'window_start': 124, 'window_end': 191, 'length': 2, 'priority': 3},
#  396: {'window_start': 3, 'window_end': 60, 'length': 32, 'priority': 4},
#  397: {'window_start': 58, 'window_end': 125, 'length': 43, 'priority': 4},
#  398: {'window_start': 25, 'window_end': 91, 'length': 45, 'priority': 4},
#  399: {'window_start': 45, 'window_end': 241, 'length': 33, 'priority': 1},
#  400: {'window_start': 95, 'window_end': 129, 'length': 18, 'priority': 2},
#  401: {'window_start': 147, 'window_end': 242, 'length': 24, 'priority': 5},
#  402: {'window_start': 163, 'window_end': 228, 'length': 37, 'priority': 5},
#  403: {'window_start': 12, 'window_end': 218, 'length': 31, 'priority': 4},
#  404: {'window_start': 231, 'window_end': 259, 'length': 28, 'priority': 5},
#  405: {'window_start': 154, 'window_end': 252, 'length': 5, 'priority': 3},
#  406: {'window_start': 67, 'window_end': 210, 'length': 13, 'priority': 2},
#  407: {'window_start': 137, 'window_end': 241, 'length': 37, 'priority': 3},
#  408: {'window_start': 224, 'window_end': 261, 'length': 24, 'priority': 4},
#  409: {'window_start': 3, 'window_end': 219, 'length': 2, 'priority': 1},
#  410: {'window_start': 99, 'window_end': 191, 'length': 36, 'priority': 5},
#  411: {'window_start': 76, 'window_end': 195, 'length': 2, 'priority': 5},
#  412: {'window_start': 82, 'window_end': 124, 'length': 13, 'priority': 1},
#  413: {'window_start': 116, 'window_end': 147, 'length': 31, 'priority': 2},
#  414: {'window_start': 9, 'window_end': 251, 'length': 44, 'priority': 5},
#  415: {'window_start': 57, 'window_end': 125, 'length': 35, 'priority': 1},
#  416: {'window_start': 126, 'window_end': 258, 'length': 39, 'priority': 2},
#  417: {'window_start': 83, 'window_end': 88, 'length': 5, 'priority': 5},
#  418: {'window_start': 161, 'window_end': 260, 'length': 17, 'priority': 1},
#  419: {'window_start': 46, 'window_end': 61, 'length': 15, 'priority': 2},
#  420: {'window_start': 214, 'window_end': 259, 'length': 45, 'priority': 3},
#  421: {'window_start': 70, 'window_end': 132, 'length': 33, 'priority': 4},
#  422: {'window_start': 164, 'window_end': 202, 'length': 38, 'priority': 4},
#  423: {'window_start': 59, 'window_end': 112, 'length': 28, 'priority': 1},
#  424: {'window_start': 36, 'window_end': 90, 'length': 9, 'priority': 4},
#  425: {'window_start': 61, 'window_end': 107, 'length': 33, 'priority': 1},
#  426: {'window_start': 226, 'window_end': 277, 'length': 31, 'priority': 1},
#  427: {'window_start': 188, 'window_end': 254, 'length': 3, 'priority': 4},
#  428: {'window_start': 36, 'window_end': 90, 'length': 27, 'priority': 1},
#  429: {'window_start': 91, 'window_end': 211, 'length': 23, 'priority': 2},
#  430: {'window_start': 40, 'window_end': 215, 'length': 26, 'priority': 1},
#  431: {'window_start': 182, 'window_end': 293, 'length': 23, 'priority': 2},
#  432: {'window_start': 168, 'window_end': 272, 'length': 22, 'priority': 4},
#  433: {'window_start': 185, 'window_end': 218, 'length': 6, 'priority': 1},
#  434: {'window_start': 95, 'window_end': 217, 'length': 11, 'priority': 4},
#  435: {'window_start': 57, 'window_end': 227, 'length': 42, 'priority': 4},
#  436: {'window_start': 74, 'window_end': 182, 'length': 36, 'priority': 1},
#  437: {'window_start': 187, 'window_end': 235, 'length': 29, 'priority': 3},
#  438: {'window_start': 14, 'window_end': 153, 'length': 50, 'priority': 5},
#  439: {'window_start': 142, 'window_end': 147, 'length': 5, 'priority': 4},
#  440: {'window_start': 43, 'window_end': 175, 'length': 29, 'priority': 2},
#  441: {'window_start': 5, 'window_end': 229, 'length': 7, 'priority': 4},
#  442: {'window_start': 116, 'window_end': 176, 'length': 33, 'priority': 3},
#  443: {'window_start': 3, 'window_end': 138, 'length': 48, 'priority': 2},
#  444: {'window_start': 12, 'window_end': 210, 'length': 21, 'priority': 4},
#  445: {'window_start': 51, 'window_end': 134, 'length': 41, 'priority': 5},
#  446: {'window_start': 113, 'window_end': 131, 'length': 18, 'priority': 3},
#  447: {'window_start': 12, 'window_end': 266, 'length': 8, 'priority': 3},
#  448: {'window_start': 79, 'window_end': 189, 'length': 2, 'priority': 3},
#  449: {'window_start': 93, 'window_end': 95, 'length': 2, 'priority': 2},
#  450: {'window_start': 14, 'window_end': 192, 'length': 45, 'priority': 1},
#  451: {'window_start': 42, 'window_end': 273, 'length': 22, 'priority': 5},
#  452: {'window_start': 23, 'window_end': 56, 'length': 3, 'priority': 3},
#  453: {'window_start': 138, 'window_end': 246, 'length': 29, 'priority': 1},
#  454: {'window_start': 105, 'window_end': 139, 'length': 31, 'priority': 4},
#  455: {'window_start': 95, 'window_end': 155, 'length': 31, 'priority': 5},
#  456: {'window_start': 75, 'window_end': 104, 'length': 26, 'priority': 4},
#  457: {'window_start': 43, 'window_end': 266, 'length': 37, 'priority': 3},
#  458: {'window_start': 235, 'window_end': 242, 'length': 7, 'priority': 1},
#  459: {'window_start': 69, 'window_end': 286, 'length': 36, 'priority': 4},
#  460: {'window_start': 189, 'window_end': 235, 'length': 30, 'priority': 5},
#  461: {'window_start': 184, 'window_end': 189, 'length': 5, 'priority': 5},
#  462: {'window_start': 119, 'window_end': 187, 'length': 13, 'priority': 2},
#  463: {'window_start': 107, 'window_end': 243, 'length': 1, 'priority': 3},
#  464: {'window_start': 260, 'window_end': 287, 'length': 12, 'priority': 3},
#  465: {'window_start': 26, 'window_end': 123, 'length': 3, 'priority': 1},
#  466: {'window_start': 46, 'window_end': 214, 'length': 23, 'priority': 5},
#  467: {'window_start': 123, 'window_end': 182, 'length': 20, 'priority': 3},
#  468: {'window_start': 192, 'window_end': 222, 'length': 30, 'priority': 2},
#  469: {'window_start': 86, 'window_end': 262, 'length': 47, 'priority': 5},
#  470: {'window_start': 7, 'window_end': 141, 'length': 42, 'priority': 2},
#  471: {'window_start': 145, 'window_end': 220, 'length': 2, 'priority': 4},
#  472: {'window_start': 158, 'window_end': 237, 'length': 5, 'priority': 4},
#  473: {'window_start': 223, 'window_end': 291, 'length': 36, 'priority': 5},
#  474: {'window_start': 27, 'window_end': 87, 'length': 30, 'priority': 2},
#  475: {'window_start': 245, 'window_end': 273, 'length': 28, 'priority': 3},
#  476: {'window_start': 29, 'window_end': 97, 'length': 36, 'priority': 3},
#  477: {'window_start': 61, 'window_end': 187, 'length': 12, 'priority': 4},
#  478: {'window_start': 10, 'window_end': 127, 'length': 37, 'priority': 5},
#  479: {'window_start': 101, 'window_end': 128, 'length': 27, 'priority': 2},
#  480: {'window_start': 134, 'window_end': 209, 'length': 24, 'priority': 1},
#  481: {'window_start': 3, 'window_end': 122, 'length': 2, 'priority': 4},
#  482: {'window_start': 83, 'window_end': 124, 'length': 40, 'priority': 1},
#  483: {'window_start': 109, 'window_end': 261, 'length': 40, 'priority': 2},
#  484: {'window_start': 121, 'window_end': 220, 'length': 28, 'priority': 5},
#  485: {'window_start': 39, 'window_end': 162, 'length': 1, 'priority': 1},
#  486: {'window_start': 115, 'window_end': 142, 'length': 16, 'priority': 1},
#  487: {'window_start': 256, 'window_end': 289, 'length': 9, 'priority': 1},
#  488: {'window_start': 218, 'window_end': 265, 'length': 47, 'priority': 2},
#  489: {'window_start': 119, 'window_end': 182, 'length': 27, 'priority': 1},
#  490: {'window_start': 0, 'window_end': 34, 'length': 16, 'priority': 1},
#  491: {'window_start': 38, 'window_end': 255, 'length': 36, 'priority': 2},
#  492: {'window_start': 62, 'window_end': 140, 'length': 27, 'priority': 4},
#  493: {'window_start': 15, 'window_end': 182, 'length': 6, 'priority': 5},
#  494: {'window_start': 47, 'window_end': 242, 'length': 39, 'priority': 5},
#  495: {'window_start': 55, 'window_end': 299, 'length': 21, 'priority': 1},
#  496: {'window_start': 56, 'window_end': 164, 'length': 45, 'priority': 3},
#  497: {'window_start': 67, 'window_end': 107, 'length': 19, 'priority': 3},
#  498: {'window_start': 106, 'window_end': 215, 'length': 22, 'priority': 3},
#  499: {'window_start': 165, 'window_end': 259, 'length': 31, 'priority': 5}}
