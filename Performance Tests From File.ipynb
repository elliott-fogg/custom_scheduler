# %% [markdown]
# # Import Libraries

# %%
from test_template_from_file import AltPerformanceTest, AltPerformanceTestParser, SolverComparisonTest

# %% [markdown]
# # Performance Tests

# %% [markdown]
# ## Performance Test 1

# %%
pt1 = AltPerformanceTest("performance_input", "performance_output", "performanceTest1")
pt1.run()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 pt1 = AltPerformanceTest("performance_input", "performance_output", "performanceTest1")
#       2 pt1.run()
#
# File ~\Documents\LCO\custom_scheduler\test_template_from_file.py:22, in AltPerformanceTest.__init__(self, input_folder, output_folder, file_identifier, scheduler_type)
#      19 self.output_dir = os.path.join(output_folder, file_identifier)
#      20 os.makedirs(self.output_dir, exist_ok=True)
# ---> 22 all_input_files = self.gather_input_files(file_identifier)
#      23 self.input_files = self.check_input_files(all_input_files)
#      25 self.total_iterations = len(self.input_files)
#
# File ~\Documents\LCO\custom_scheduler\test_template_from_file.py:30, in AltPerformanceTest.gather_input_files(self, file_identifier)
#      29 def gather_input_files(self, file_identifier):
# ...

# %% [markdown]
# ## Performance Test 2

# %%
pt2 = AltPerformanceTest("performance_input", "performance_output", "performanceTest2")
pt2.run()
# Out:
# 70  files remaining.
# 1 / 70 - performanceTest2_10Telescopes_100Requests_0.json - 23:23:55 25-02-2024
# 2 / 70 - performanceTest2_10Telescopes_100Requests_1.json - 23:23:56 25-02-2024
# 3 / 70 - performanceTest2_10Telescopes_100Requests_2.json - 23:23:56 25-02-2024
# 4 / 70 - performanceTest2_10Telescopes_100Requests_3.json - 23:23:58 25-02-2024
# 5 / 70 - performanceTest2_10Telescopes_100Requests_4.json - 23:23:59 25-02-2024
# 6 / 70 - performanceTest2_10Telescopes_100Requests_5.json - 23:24:00 25-02-2024
# 7 / 70 - performanceTest2_10Telescopes_100Requests_6.json - 23:24:01 25-02-2024
# 8 / 70 - performanceTest2_10Telescopes_100Requests_7.json - 23:24:02 25-02-2024
# 9 / 70 - performanceTest2_10Telescopes_100Requests_8.json - 23:24:03 25-02-2024
# 10 / 70 - performanceTest2_10Telescopes_100Requests_9.json - 23:24:04 25-02-2024
# 11 / 70 - performanceTest2_15Telescopes_100Requests_0.json - 23:24:05 25-02-2024
# ...

# %% [markdown]
# ## Performance Test 3

# %%
pt3 = AltPerformanceTest("performance_input", "performance_output", "performanceTest3")
pt3.run()
# Out:
# 70  files remaining.
# 1 / 70 - performanceTest3_120SliceSize_100Requests_0.json - 23:24:56 25-02-2024
# 2 / 70 - performanceTest3_120SliceSize_100Requests_1.json - 23:24:56 25-02-2024
# 3 / 70 - performanceTest3_120SliceSize_100Requests_2.json - 23:24:57 25-02-2024
# 4 / 70 - performanceTest3_120SliceSize_100Requests_3.json - 23:24:58 25-02-2024
# 5 / 70 - performanceTest3_120SliceSize_100Requests_4.json - 23:24:58 25-02-2024
# 6 / 70 - performanceTest3_120SliceSize_100Requests_5.json - 23:24:59 25-02-2024
# 7 / 70 - performanceTest3_120SliceSize_100Requests_6.json - 23:24:59 25-02-2024
# 8 / 70 - performanceTest3_120SliceSize_100Requests_7.json - 23:25:00 25-02-2024
# 9 / 70 - performanceTest3_120SliceSize_100Requests_8.json - 23:25:00 25-02-2024
# 10 / 70 - performanceTest3_120SliceSize_100Requests_9.json - 23:25:01 25-02-2024
# 11 / 70 - performanceTest3_180SliceSize_100Requests_0.json - 23:25:01 25-02-2024
# ...

# %% [markdown]
# ## Performance Test 5

# %%
pt5 = AltPerformanceTest("performance_input", "performance_output", "performanceTest5")
pt5.run()

# %% [markdown]
# ## Performance Test 6

# %%
pt6 = AltPerformanceTest("performance_input", "performance_output", "performanceTest6")
pt6.run()
# Out:
# 40  files remaining.
# 1 / 40 - performanceTest6_1Networks_8Telescopes_200GrossRequests_0.json - 23:26:46 25-02-2024
# 2 / 40 - performanceTest6_1Networks_8Telescopes_200GrossRequests_1.json - 23:26:48 25-02-2024
# 3 / 40 - performanceTest6_1Networks_8Telescopes_200GrossRequests_2.json - 23:26:50 25-02-2024
# 4 / 40 - performanceTest6_1Networks_8Telescopes_200GrossRequests_3.json - 23:26:51 25-02-2024
# 5 / 40 - performanceTest6_1Networks_8Telescopes_200GrossRequests_4.json - 23:26:53 25-02-2024
# 6 / 40 - performanceTest6_1Networks_8Telescopes_200GrossRequests_5.json - 23:26:55 25-02-2024
# 7 / 40 - performanceTest6_1Networks_8Telescopes_200GrossRequests_6.json - 23:26:57 25-02-2024
# 8 / 40 - performanceTest6_1Networks_8Telescopes_200GrossRequests_7.json - 23:26:59 25-02-2024
# 9 / 40 - performanceTest6_1Networks_8Telescopes_200GrossRequests_8.json - 23:27:01 25-02-2024
# 10 / 40 - performanceTest6_1Networks_8Telescopes_200GrossRequests_9.json - 23:27:03 25-02-2024
# ...

# %% [markdown]
# ## Performance Test 7

# %%
pt7 = AltPerformanceTest("performance_input", "performance_output", "performanceTest7")
pt7.run()
# Out:
# 400  files remaining.
# 1 / 400 - performanceTest7_10HorizonDays_10000Requests_0.json - 22:04:24 28-02-2024
# 2 / 400 - performanceTest7_10HorizonDays_10000Requests_1.json - 22:04:45 28-02-2024
# 3 / 400 - performanceTest7_10HorizonDays_10000Requests_2.json - 22:05:13 28-02-2024
# 4 / 400 - performanceTest7_10HorizonDays_10000Requests_3.json - 22:05:42 28-02-2024
# 5 / 400 - performanceTest7_10HorizonDays_10000Requests_4.json - 22:06:12 28-02-2024
# 6 / 400 - performanceTest7_10HorizonDays_10000Requests_5.json - 22:06:42 28-02-2024
# 7 / 400 - performanceTest7_10HorizonDays_10000Requests_6.json - 22:07:06 28-02-2024
# 8 / 400 - performanceTest7_10HorizonDays_10000Requests_7.json - 22:07:30 28-02-2024
# 9 / 400 - performanceTest7_10HorizonDays_10000Requests_8.json - 22:08:09 28-02-2024
# 10 / 400 - performanceTest7_10HorizonDays_10000Requests_9.json - 22:08:40 28-02-2024
# 11 / 400 - performanceTest7_10HorizonDays_1000Requests_0.json - 22:09:08 28-02-2024
# ...

# %% [markdown]
# # Solver Comparison

# %% [markdown]
# ## Performance Test 1

# %% [markdown]
# ### Gurobi

# %%
ptg1 = SolverComparisonTest("data/performance_input", "data/comparison_output", "performanceTest1", scheduler_type="gurobi")
ptg1.run()
# Out:
# File completed: performanceTest1_100Requests_0_gurobi.json
# 0  files remaining.
# 1  files remaining.
# 2  files remaining.
# 3  files remaining.
# 4  files remaining.
# 5  files remaining.
# 6  files remaining.
# 7  files remaining.
# 8  files remaining.
# 9  files remaining.
# 10  files remaining.
# 11  files remaining.
# 12  files remaining.
# 13  files remaining.
# 14  files remaining.
# 15  files remaining.
# 16  files remaining.
# 17  files remaining.
# 18  files remaining.
# 19  files remaining.
# 20  files remaining.
# 21  files remaining.
# 22  files remaining.
# 23  files remaining.
# 24  files remaining.
# 25  files remaining.
# 26  files remaining.
# 27  files remaining.
# 28  files remaining.
# 29  files remaining.
# 30  files remaining.
# 31  files remaining.
# 32  files remaining.
# 33  files remaining.
# 34  files remaining.
# 35  files remaining.
# 36  files remaining.
# 37  files remaining.
# 38  files remaining.
# 39  files remaining.
# 40  files remaining.
# ...

# %% [markdown]
# ### CPSAT

# %%
pt1_cpsat = SolverComparisonTest("data/performance_input", "data/comparison_output", "performanceTest1", scheduler_type="cpsat")
pt1_cpsat.run()
# Out:
# 50  files remaining.
# 1 / 50 - performanceTest1_100Requests_0.json - 11:13:30 11-03-2024
# 2 / 50 - performanceTest1_100Requests_1.json - 11:13:31 11-03-2024
# 3 / 50 - performanceTest1_100Requests_2.json - 11:13:31 11-03-2024
# 4 / 50 - performanceTest1_100Requests_3.json - 11:13:31 11-03-2024
# 5 / 50 - performanceTest1_100Requests_4.json - 11:13:31 11-03-2024
# 6 / 50 - performanceTest1_100Requests_5.json - 11:13:31 11-03-2024
# 7 / 50 - performanceTest1_100Requests_6.json - 11:13:31 11-03-2024
# 8 / 50 - performanceTest1_100Requests_7.json - 11:13:31 11-03-2024
# 9 / 50 - performanceTest1_100Requests_8.json - 11:13:32 11-03-2024
# 10 / 50 - performanceTest1_100Requests_9.json - 11:13:32 11-03-2024
# 11 / 50 - performanceTest1_200Requests_0.json - 11:13:32 11-03-2024
# 12 / 50 - performanceTest1_200Requests_1.json - 11:13:32 11-03-2024
# 13 / 50 - performanceTest1_200Requests_2.json - 11:13:33 11-03-2024
# 14 / 50 - performanceTest1_200Requests_3.json - 11:13:33 11-03-2024
# ...

# %% [markdown]
# ### CBC

# %%
pt1_cbc = SolverComparisonTest("data/performance_input", "data/comparison_output", "performanceTest1", scheduler_type="cbc")
pt1_cbc.run()
# Out:
# 50  files remaining.
# 1 / 50 - performanceTest1_100Requests_0.json - 17:53:02 08-03-2024
# performanceTest1_100Requests_0_cbc.json
# 2 / 50 - performanceTest1_100Requests_1.json - 17:53:02 08-03-2024
# performanceTest1_100Requests_1_cbc.json
# 3 / 50 - performanceTest1_100Requests_2.json - 17:53:02 08-03-2024
# performanceTest1_100Requests_2_cbc.json
# 4 / 50 - performanceTest1_100Requests_3.json - 17:53:02 08-03-2024
# performanceTest1_100Requests_3_cbc.json
# 5 / 50 - performanceTest1_100Requests_4.json - 17:53:03 08-03-2024
# performanceTest1_100Requests_4_cbc.json
# 6 / 50 - performanceTest1_100Requests_5.json - 17:53:03 08-03-2024
# performanceTest1_100Requests_5_cbc.json
# 7 / 50 - performanceTest1_100Requests_6.json - 17:53:03 08-03-2024
# performanceTest1_100Requests_6_cbc.json
# 8 / 50 - performanceTest1_100Requests_7.json - 17:53:03 08-03-2024
# performanceTest1_100Requests_7_cbc.json
# 9 / 50 - performanceTest1_100Requests_8.json - 17:53:03 08-03-2024
# ...

# %% [markdown]
# ### SCIP

# %%
pt1_scip = SolverComparisonTest("data/performance_input", "data/comparison_output", "performanceTest1", scheduler_type="scip")
pt1_scip.run()
# Out:
# 50  files remaining.
# 1 / 50 - performanceTest1_100Requests_0.json - 17:54:10 08-03-2024
# performanceTest1_100Requests_0_scip.json
# 2 / 50 - performanceTest1_100Requests_1.json - 17:54:10 08-03-2024
# performanceTest1_100Requests_1_scip.json
# 3 / 50 - performanceTest1_100Requests_2.json - 17:54:10 08-03-2024
# performanceTest1_100Requests_2_scip.json
# 4 / 50 - performanceTest1_100Requests_3.json - 17:54:10 08-03-2024
# performanceTest1_100Requests_3_scip.json
# 5 / 50 - performanceTest1_100Requests_4.json - 17:54:10 08-03-2024
# performanceTest1_100Requests_4_scip.json
# 6 / 50 - performanceTest1_100Requests_5.json - 17:54:10 08-03-2024
# performanceTest1_100Requests_5_scip.json
# 7 / 50 - performanceTest1_100Requests_6.json - 17:54:11 08-03-2024
# performanceTest1_100Requests_6_scip.json
# 8 / 50 - performanceTest1_100Requests_7.json - 17:54:11 08-03-2024
# performanceTest1_100Requests_7_scip.json
# 9 / 50 - performanceTest1_100Requests_8.json - 17:54:11 08-03-2024
# ...

# %% [markdown]
# ### HiGHS

# %%
pt1_highs = SolverComparisonTest("data/performance_input", "data/comparison_output", "performanceTest1", scheduler_type="highs")
pt1_highs.run()
# Out:
# 50  files remaining.
# 1 / 50 - performanceTest1_100Requests_0.json - 17:54:47 08-03-2024
# performanceTest1_100Requests_0_highs.json
# 2 / 50 - performanceTest1_100Requests_1.json - 17:54:47 08-03-2024
# performanceTest1_100Requests_1_highs.json
# 3 / 50 - performanceTest1_100Requests_2.json - 17:54:47 08-03-2024
# performanceTest1_100Requests_2_highs.json
# 4 / 50 - performanceTest1_100Requests_3.json - 17:54:47 08-03-2024
# performanceTest1_100Requests_3_highs.json
# 5 / 50 - performanceTest1_100Requests_4.json - 17:54:47 08-03-2024
# performanceTest1_100Requests_4_highs.json
# 6 / 50 - performanceTest1_100Requests_5.json - 17:54:48 08-03-2024
# performanceTest1_100Requests_5_highs.json
# 7 / 50 - performanceTest1_100Requests_6.json - 17:54:48 08-03-2024
# performanceTest1_100Requests_6_highs.json
# 8 / 50 - performanceTest1_100Requests_7.json - 17:54:48 08-03-2024
# performanceTest1_100Requests_7_highs.json
# 9 / 50 - performanceTest1_100Requests_8.json - 17:54:48 08-03-2024
# ...

# %% [markdown]
# ### PuLP Gurobi

# %%
pt1_gp = SolverComparisonTest("data/performance_input", "data/comparison_output", "performanceTest1", scheduler_type="gurobi_pulp")
pt1_gp.run()
# Out:
# 50  files remaining.
# 1 / 50 - performanceTest1_100Requests_0.json - 17:55:28 08-03-2024
# performanceTest1_100Requests_0_gurobi_pulp.json
# 2 / 50 - performanceTest1_100Requests_1.json - 17:55:28 08-03-2024
# performanceTest1_100Requests_1_gurobi_pulp.json
# 3 / 50 - performanceTest1_100Requests_2.json - 17:55:28 08-03-2024
# performanceTest1_100Requests_2_gurobi_pulp.json
# 4 / 50 - performanceTest1_100Requests_3.json - 17:55:28 08-03-2024
# performanceTest1_100Requests_3_gurobi_pulp.json
# 5 / 50 - performanceTest1_100Requests_4.json - 17:55:28 08-03-2024
# performanceTest1_100Requests_4_gurobi_pulp.json
# 6 / 50 - performanceTest1_100Requests_5.json - 17:55:29 08-03-2024
# performanceTest1_100Requests_5_gurobi_pulp.json
# 7 / 50 - performanceTest1_100Requests_6.json - 17:55:29 08-03-2024
# performanceTest1_100Requests_6_gurobi_pulp.json
# 8 / 50 - performanceTest1_100Requests_7.json - 17:55:29 08-03-2024
# performanceTest1_100Requests_7_gurobi_pulp.json
# ...

# %% [markdown]
# ### PuLP Gurobi CMD

# %%
pt1_gpc = SolverComparisonTest("data/performance_input", "data/comparison_output", "performanceTest1", scheduler_type="gurobi_pulp_cmd")
pt1_gpc.run()
# Out:
# 50  files remaining.
# 1 / 50 - performanceTest1_100Requests_0.json - 17:56:08 08-03-2024
# performanceTest1_100Requests_0_gurobi_pulp_cmd.json
# 2 / 50 - performanceTest1_100Requests_1.json - 17:56:08 08-03-2024
# performanceTest1_100Requests_1_gurobi_pulp_cmd.json
# 3 / 50 - performanceTest1_100Requests_2.json - 17:56:08 08-03-2024
# performanceTest1_100Requests_2_gurobi_pulp_cmd.json
# 4 / 50 - performanceTest1_100Requests_3.json - 17:56:08 08-03-2024
# performanceTest1_100Requests_3_gurobi_pulp_cmd.json
# 5 / 50 - performanceTest1_100Requests_4.json - 17:56:08 08-03-2024
# performanceTest1_100Requests_4_gurobi_pulp_cmd.json
# 6 / 50 - performanceTest1_100Requests_5.json - 17:56:09 08-03-2024
# performanceTest1_100Requests_5_gurobi_pulp_cmd.json
# 7 / 50 - performanceTest1_100Requests_6.json - 17:56:09 08-03-2024
# performanceTest1_100Requests_6_gurobi_pulp_cmd.json
# 8 / 50 - performanceTest1_100Requests_7.json - 17:56:09 08-03-2024
# ...
